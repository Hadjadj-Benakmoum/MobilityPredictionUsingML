# %% [markdown]
# <a href="https://colab.research.google.com/github/Hadjadj-Benakmoum/MobilityPredictionUsingML/blob/main/Hidden_Markov_Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import time
import os

# %% [markdown]
# # Mount Google drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Load/split sequences functions

# %%
def Load_Data(file):
  locations = []
  days = []
  with open(file) as f:  
     for line in f:
         locations.append(line.split()[1]) 
         if (line.split()[0]).isnumeric:
             days.append(time.strftime("%A", time.localtime(int(line.split()[0])))) 
  return locations,days

def Split_sequence(sequence,train_percentage):
  split_index = int(train_percentage * len(sequence))
  train_sequence = sequence[:split_index]
  test_sequence  = sequence[split_index:]
  return train_sequence,test_sequence

# %% [markdown]
# # Simple markove training function

# %%
def train_markov_model(locations, w,model=None):
  seq_size = len(locations)
  if(model==None):
    model={}

  for i in range(int(seq_size-1) - w):
      context = ','.join(locations[i:i+w])
      next_location = locations[i+w]
      if(context in model.keys()):
          if(next_location in model[context].keys()):
              model[context][next_location]+=1
          else:
              model[context][next_location]=1
      else:
          model[context]={next_location:1}
  return model

# %% [markdown]
# # Simple predict function based on markov

# %%
def predict_next_location(model,context):
  if (context in model.keys() ):
     next_locations_dic = model[context]
     next_loc=max(next_locations_dic,key=next_locations_dic.get)
  else:
    next_loc=None
  return next_loc

# %% [markdown]
# # Function to train HMM on one user

# %%
def extract_one_day_sequence(locations,days,i):
  ind=i
  while (ind < (len(days)-1)) and (days[ind]==days[ind+1]):
    ind = ind+1
  return locations[i:ind+1],ind+1

def train_HMM(locations,days,w,models=None):
  if(models == None):
    models={'Monday':{},'Tuesday':{},'Wednesday':{},'Thursday':{},'Friday':{},'Saturday':{},'Sunday':{}}

  i=0
  while i< (len(days)-w):
    day = days[i]
    day_locations,i = extract_one_day_sequence(locations,days,i)
    #if the lenght of the day is less than W
    if(len(day_locations)<=w):
      #print('Short day')
      continue
    models[day] = train_markov_model(day_locations,w,model=models[day])
  return models

# %% [markdown]
# # Convert a HMM model to simple markov model

# %%
#  this function to convert HMM models to just one markov model 
# To do this conversion, all days dictionaries are combined in one dictionary
# This function is used to produce a markov model used when the day model does not contain a context (but this context exist in other days) 

def convert_hmm_to_markov(models):
  markov_model={}
  for day in models:
    for context in models[day]:
      if context in markov_model:
        for next_location in models[day][context]:
          if next_location in markov_model[context]:
            markov_model[context][next_location] += models[day][context][next_location]
          else:
            markov_model[context][next_location] = models[day][context][next_location]
      else:
        markov_model[context]=models[day][context]

  return markov_model

# %% [markdown]
# # Function to test HMM on one day

# %%
def test_one_day(model,day_locations,w,otherwise_markov=False,markov_model=None):
  sequence_lenght = len(day_locations)
  correct=0
  incorrect=0
  undefined=0
  for i in range(sequence_lenght-w):
    context = ','.join(day_locations[i:i+w])
    prediction = predict_next_location(model,context)

    if prediction is None :
      if otherwise_markov:
        prediction = predict_next_location(markov_model,context)

    real_location = day_locations[i+w]

    if (prediction is None ):
        undefined +=1
    else:
        if (prediction == real_location ):
          correct +=1
        else:
          incorrect +=1
  return correct,incorrect,undefined

# %% [markdown]
# # Function to test HMM on one user

# %%
def test_user_HMM(models,test_locations,test_days,w,otherwise_markov=False,markov_model=None,activate_HMM=True):
  correct=0
  incorrect=0
  undefined=0
  short_days = 0
  i=0
  while (i < len(test_locations)):
      #print(i,len(test_days),len(test_locations))
      day = test_days[i]
      day_locations,i=extract_one_day_sequence(test_locations,test_days,i)
      
      if(len(day_locations)<=w):
        #print('Short day')
        short_days +=1
        undefined +=len(day_locations)
        continue
      
      if (activate_HMM):
        model = models[day]
      else:
        model = markov_model

      day_correct,day_incorrect,day_undefined  = test_one_day(model,day_locations,w,otherwise_markov,markov_model)
      correct += day_correct
      incorrect += day_incorrect
      undefined += day_undefined

  accuracy = correct/len(test_locations)
  return correct,incorrect,undefined,short_days,accuracy

# %% [markdown]
# # HMM training verification

# %%
w = 8
file_name = '/content/drive/My Drive/Mobility test/0000c5112528.log.mv'
locations,days = Load_Data(file_name)

train_locations,test_locations = Split_sequence(locations,train_percentage=0.8)
train_days,test_days = Split_sequence(days,train_percentage=0.8)

print(len(train_locations),len(test_locations))
print(len(train_days),len(test_days))

models = None
models = train_HMM(train_locations,train_days,w=8)
markov_model = convert_hmm_to_markov(models)
print(test_user_HMM(models,test_locations,test_days,w=8,otherwise_markov=False,markov_model=markov_model,activate_HMM=False))
print(test_user_HMM(models,test_locations,test_days,w=8,otherwise_markov=False,markov_model=markov_model))
print(test_user_HMM(models,test_locations,test_days,w=8,otherwise_markov=True,markov_model=markov_model))
# Out:
# 1524 382
# 1524 382
# (369, 3, 2, 1, 0.9659685863874345)
# (362, 2, 10, 1, 0.9476439790575916)
# (369, 3, 2, 1, 0.9659685863874345)

# %% [markdown]
# # **Test Scenario 1** : Train/Test in each user

# %%
#Test configuration
w=1
train_percentage=0.8
threshold_lenght = 1000
method = 'HMM'


#undefined_strategy = 'None'
undefined_strategy = 'Markov'


path='/content/drive/My Drive/Mobility test/'
activate_HMM = True
otherwise_test_markov = False
if(undefined_strategy == 'Markov'):
  otherwise_test_markov = True

test_configuration ='Scenario:{0} W:{1} Method:{2} undefined_strategy:{3}.csv'.format(1,w,method,undefined_strategy)
print('Test strategy : ', test_configuration)
# Out:
# Test strategy :  Scenario:1 W:1 Method:HMM undefined_strategy:Markov.csv

# %%
import csv
def save_results_csv(output_file,users_files,Corrects,Incorrects,Undefined,Shortdays,Accuracies):
  with open(output_file, 'w') as csvfile:
      header = ['output_file','users_files','Corrects','Incorrects','Undefined','Shortdays','Accuracies']
      writer = csv.writer(csvfile, delimiter=',')
      writer.writerow(header)
      outputs = zip(users_files,Corrects,Incorrects,Undefined,Shortdays,Accuracies)
      writer.writerows(outputs)

# %%
Accuracies=[]
Corrects=[]
Incorrects=[]
Undefined=[]
Shortdays=[]
users_files =  os.listdir(path)
print('Number of files :',len(users_files))
for filename in users_files:
    if filename.endswith("mv"):
      #Read sequence
      locations,days = Load_Data(os.path.join(path,filename))
      
      #Ignore sequence if the lenght is less than threshold_lenght
      if(len(locations)<threshold_lenght):
        continue

      #Split the sequence Train/Test
      train_locations,test_locations = Split_sequence(locations,train_percentage)
      train_days,test_days = Split_sequence(days,train_percentage)

      #Train the HMM model 
      models = None
      models = train_HMM(train_locations,train_days,w)

      #Convert the HMM model to normal markov model. This simple markove model use is used if a context is absent in the day model
      markov_model = train_markov_model(train_locations,w)

      #Test the Model 
      user_correct,user_incorrect,user_undefined,user_short_day,user_accuracy = test_user_HMM(models,
                                                                                              test_locations,
                                                                                              test_days,
                                                                                              w,
                                                                                              otherwise_markov=otherwise_test_markov,
                                                                                              markov_model=markov_model,
                                                                                              activate_HMM= activate_HMM)
      
      #Collect results
      Corrects.append(user_correct)
      Incorrects.append(user_incorrect)
      Undefined.append(user_undefined)
      Shortdays.append(user_short_day)
      Accuracies.append(user_accuracy)
      
      #Display results
      print('User : ', filename)
      print('User lenght : ',len(locations))
      print('Correct : ',user_correct )
      print('Incorrect : ',user_incorrect)
      print('Undefined : ',user_undefined)
      print('User short days : ',user_short_day)
      print('Accuracy : ',user_accuracy)
      print("======================================================================================================")

#Save final results in csv file where the name contains information about the test (w,method ....). The name of file is : Configuration.csv
save_results_csv(test_configuration,users_files,Corrects,Incorrects,Undefined,Shortdays,Accuracies)

print('Global results : ')
print("======================================================================================================")
print('Corrects : ',sum(Corrects))
print('Incorrects : ',sum(Incorrects))
print('Short days : ',sum(Undefined))
print('Undefined_Sequences : ',sum(Shortdays))
print('Average Acc : ',sum(Accuracies)/len(Accuracies))
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
# User :  000750615ac5.log.mv
# User lenght :  1022
# Correct :  33
# Incorrect :  63
# Undefined :  77
# User short days :  0
# Accuracy :  0.16097560975609757
# ======================================================================================================
# User :  00070e661235.log.mv
# User lenght :  1795
# Correct :  92
# Incorrect :  215
# Undefined :  12
# User short days :  2
# Accuracy :  0.2562674094707521
# ======================================================================================================
# User :  000625a559b5.log.mv
# User lenght :  1844
# Correct :  288
# Incorrect :  49
# Undefined :  14
# User short days :  1
# Accuracy :  0.7804878048780488
# ======================================================================================================
# User :  00053cb1ad35.log.mv
# User lenght :  2856
# Correct :  229
# Incorrect :  299
# Undefined :  3
# User short days :  0
# Accuracy :  0.40034965034965037
# ======================================================================================================
# User :  00070e703c25.log.mv
# User lenght :  9966
# Correct :  915
# Incorrect :  1001
# Undefined :  50
# User short days :  7
# Accuracy :  0.458876629889669
# ======================================================================================================
# User :  000625cb41a5.log.mv
# User lenght :  3999
# Correct :  782
# Incorrect :  0
# Undefined :  0
# User short days :  0
# Accuracy :  0.9775
# ======================================================================================================
# User :  0002b37d5ad5.log.mv
# User lenght :  2701
# Correct :  152
# Incorrect :  288
# Undefined :  70
# User short days :  0
# Accuracy :  0.2809611829944547
# ======================================================================================================
# User :  00053c0b5c65.log.mv
# User lenght :  7050
# Correct :  1205
# Incorrect :  175
# Undefined :  2
# User short days :  0
# Accuracy :  0.8546099290780141
# ======================================================================================================
# User :  0006259fd785.log.mv
# User lenght :  3245
# Correct :  321
# Incorrect :  257
# Undefined :  27
# User short days :  1
# Accuracy :  0.4946070878274268
# ======================================================================================================
# User :  003065097145.log.mv
# User lenght :  1535
# Correct :  278
# Incorrect :  25
# Undefined :  0
# User short days :  0
# Accuracy :  0.9055374592833876
# ======================================================================================================
# User :  0030650b29a5.log.mv
# User lenght :  3157
# Correct :  92
# Incorrect :  437
# Undefined :  62
# User short days :  0
# Accuracy :  0.14556962025316456
# ======================================================================================================
# User :  003065370b25.log.mv
# User lenght :  6308
# Correct :  591
# Incorrect :  555
# Undefined :  40
# User short days :  2
# Accuracy :  0.4683042789223455
# ======================================================================================================
# User :  003065aeaa45.log.mv
# User lenght :  2821
# Correct :  197
# Incorrect :  290
# Undefined :  42
# User short days :  0
# Accuracy :  0.3486725663716814
# ======================================================================================================
# User :  000b5fc863c5.log.mv
# User lenght :  9577
# Correct :  1324
# Incorrect :  575
# Undefined :  6
# User short days :  0
# Accuracy :  0.6910229645093946
# ======================================================================================================
# User :  0030654c8515.log.mv
# User lenght :  1275
# Correct :  113
# Incorrect :  78
# Undefined :  36
# User short days :  0
# Accuracy :  0.44313725490196076
# ======================================================================================================
# User :  0030655b9345.log.mv
# User lenght :  1803
# Correct :  92
# Incorrect :  234
# Undefined :  9
# User short days :  0
# Accuracy :  0.2548476454293629
# ======================================================================================================
# User :  00306564c4a5.log.mv
# User lenght :  2593
# Correct :  420
# Incorrect :  47
# Undefined :  6
# User short days :  0
# Accuracy :  0.8092485549132948
# ======================================================================================================
# User :  0030656742f5.log.mv
# User lenght :  1597
# Correct :  184
# Incorrect :  79
# Undefined :  29
# User short days :  1
# Accuracy :  0.575
# ======================================================================================================
# User :  000821aa0035.log.mv
# User lenght :  12056
# Correct :  1587
# Incorrect :  486
# Undefined :  259
# User short days :  3
# Accuracy :  0.6579601990049752
# ======================================================================================================
# User :  0030654d8615.log.mv
# User lenght :  6715
# Correct :  753
# Incorrect :  544
# Undefined :  7
# User short days :  0
# Accuracy :  0.5606850335070737
# ======================================================================================================
# User :  0030652529c5.log.mv
# User lenght :  2026
# Correct :  394
# Incorrect :  1
# Undefined :  2
# User short days :  2
# Accuracy :  0.9704433497536946
# ======================================================================================================
# User :  0030652cb0d5.log.mv
# User lenght :  1196
# Correct :  50
# Incorrect :  160
# Undefined :  1
# User short days :  1
# Accuracy :  0.20833333333333334
# ======================================================================================================
# User :  0030655b9b55.log.mv
# User lenght :  12329
# Correct :  1193
# Incorrect :  1203
# Undefined :  25
# User short days :  1
# Accuracy :  0.483779399837794
# ======================================================================================================
# User :  0030653bd165.log.mv
# User lenght :  3755
# Correct :  323
# Incorrect :  269
# Undefined :  100
# User short days :  3
# Accuracy :  0.43009320905459386
# ======================================================================================================
# User :  0030659166b5.log.mv
# User lenght :  3515
# Correct :  313
# Incorrect :  278
# Undefined :  74
# User short days :  4
# Accuracy :  0.44523470839260315
# ======================================================================================================
# User :  0030655f1785.log.mv
# User lenght :  2626
# Correct :  388
# Incorrect :  39
# Undefined :  58
# User short days :  1
# Accuracy :  0.7376425855513308
# ======================================================================================================
# User :  00306583b135.log.mv
# User lenght :  2950
# Correct :  334
# Incorrect :  180
# Undefined :  27
# User short days :  0
# Accuracy :  0.5661016949152542
# ======================================================================================================
# User :  0030651fa2c5.log.mv
# User lenght :  10340
# Correct :  1310
# Incorrect :  458
# Undefined :  223
# User short days :  0
# Accuracy :  0.6334622823984526
# ======================================================================================================
# User :  00306518eb65.log.mv
# User lenght :  1360
# Correct :  62
# Incorrect :  137
# Undefined :  34
# User short days :  1
# Accuracy :  0.22794117647058823
# ======================================================================================================
# User :  0009b7fa20b5.log.mv
# User lenght :  1362
# Correct :  38
# Incorrect :  189
# Undefined :  16
# User short days :  6
# Accuracy :  0.1391941391941392
# ======================================================================================================
# User :  00306573cdf5.log.mv
# User lenght :  5135
# Correct :  548
# Incorrect :  440
# Undefined :  3
# User short days :  0
# Accuracy :  0.5335929892891919
# ======================================================================================================
# User :  003065542285.log.mv
# User lenght :  1112
# Correct :  2
# Incorrect :  23
# Undefined :  180
# User short days :  2
# Accuracy :  0.008968609865470852
# ======================================================================================================
# User :  00306586db65.log.mv
# User lenght :  2266
# Correct :  51
# Incorrect :  366
# Undefined :  15
# User short days :  2
# Accuracy :  0.11233480176211454
# ======================================================================================================
# User :  00306593d275.log.mv
# User lenght :  17392
# Correct :  1751
# Incorrect :  1481
# Undefined :  93
# User short days :  2
# Accuracy :  0.5033055475711411
# ======================================================================================================
# User :  003065e785d5.log.mv
# User lenght :  1144
# Correct :  96
# Incorrect :  86
# Undefined :  11
# User short days :  5
# Accuracy :  0.4192139737991266
# ======================================================================================================
# User :  0040966c3ca5.log.mv
# User lenght :  2913
# Correct :  220
# Incorrect :  289
# Undefined :  10
# User short days :  5
# Accuracy :  0.37735849056603776
# ======================================================================================================
# User :  004096b39235.log.mv
# User lenght :  3327
# Correct :  352
# Incorrect :  246
# Undefined :  8
# User short days :  1
# Accuracy :  0.5285285285285285
# ======================================================================================================
# User :  004096d75125.log.mv
# User lenght :  1537
# Correct :  141
# Incorrect :  89
# Undefined :  1
# User short days :  0
# Accuracy :  0.4577922077922078
# ======================================================================================================
# User :  003065f97eb5.log.mv
# User lenght :  1205
# Correct :  181
# Incorrect :  22
# Undefined :  1
# User short days :  0
# Accuracy :  0.7510373443983402
# ======================================================================================================
# User :  004096d98b75.log.mv
# User lenght :  2612
# Correct :  85
# Incorrect :  359
# Undefined :  17
# User short days :  2
# Accuracy :  0.16252390057361377
# ======================================================================================================
# User :  0050dadbe785.log.mv
# User lenght :  1144
# Correct :  164
# Incorrect :  58
# Undefined :  0
# User short days :  0
# Accuracy :  0.7161572052401747
# ======================================================================================================
# User :  003065c11935.log.mv
# User lenght :  5489
# Correct :  266
# Incorrect :  369
# Undefined :  328
# User short days :  1
# Accuracy :  0.24225865209471767
# ======================================================================================================
# User :  0040960a6595.log.mv
# User lenght :  3272
# Correct :  143
# Incorrect :  473
# Undefined :  7
# User short days :  4
# Accuracy :  0.2183206106870229
# ======================================================================================================
# User :  0040963c1d25.log.mv
# User lenght :  3081
# Correct :  170
# Incorrect :  397
# Undefined :  27
# User short days :  0
# Accuracy :  0.2755267423014587
# ======================================================================================================
# User :  003065d453c5.log.mv
# User lenght :  1259
# Correct :  176
# Incorrect :  45
# Undefined :  5
# User short days :  0
# Accuracy :  0.6984126984126984
# ======================================================================================================
# User :  003065b21b85.log.mv
# User lenght :  2503
# Correct :  217
# Incorrect :  238
# Undefined :  17
# User short days :  0
# Accuracy :  0.43313373253493015
# ======================================================================================================
# User :  0000c5f2dae6.log.mv
# User lenght :  2490
# Correct :  496
# Incorrect :  1
# Undefined :  0
# User short days :  0
# Accuracy :  0.9959839357429718
# ======================================================================================================
# User :  003065d708e5.log.mv
# User lenght :  2582
# Correct :  84
# Incorrect :  266
# Undefined :  125
# User short days :  1
# Accuracy :  0.16247582205029013
# ======================================================================================================
# User :  003065dba815.log.mv
# User lenght :  1931
# Correct :  61
# Incorrect :  175
# Undefined :  61
# User short days :  10
# Accuracy :  0.15762273901808785
# ======================================================================================================
# User :  003065bd27f5.log.mv
# User lenght :  4467
# Correct :  449
# Incorrect :  309
# Undefined :  108
# User short days :  0
# Accuracy :  0.5022371364653244
# ======================================================================================================
# User :  0040967ad665.log.mv
# User lenght :  1652
# Correct :  287
# Incorrect :  38
# Undefined :  0
# User short days :  0
# Accuracy :  0.8670694864048338
# ======================================================================================================
# User :  0050dac184a5.log.mv
# User lenght :  9890
# Correct :  709
# Incorrect :  1116
# Undefined :  76
# User short days :  0
# Accuracy :  0.3584428715874621
# ======================================================================================================
# User :  003065dca955.log.mv
# User lenght :  1046
# Correct :  174
# Incorrect :  1
# Undefined :  4
# User short days :  1
# Accuracy :  0.8285714285714286
# ======================================================================================================
# User :  003065c3dfa5.log.mv
# User lenght :  5028
# Correct :  701
# Incorrect :  278
# Undefined :  5
# User short days :  0
# Accuracy :  0.6968190854870775
# ======================================================================================================
# User :  0030abb484a5.log.mv
# User lenght :  1082
# Correct :  111
# Incorrect :  104
# Undefined :  0
# User short days :  0
# Accuracy :  0.511520737327189
# ======================================================================================================
# User :  003065c6cc25.log.mv
# User lenght :  1161
# Correct :  97
# Incorrect :  93
# Undefined :  4
# User short days :  2
# Accuracy :  0.41630901287553645
# ======================================================================================================
# User :  003065f10395.log.mv
# User lenght :  1188
# Correct :  96
# Incorrect :  109
# Undefined :  3
# User short days :  1
# Accuracy :  0.40336134453781514
# ======================================================================================================
# User :  004096f3e315.log.mv
# User lenght :  1679
# Correct :  78
# Incorrect :  178
# Undefined :  30
# User short days :  0
# Accuracy :  0.23214285714285715
# ======================================================================================================
# User :  004096a6a965.log.mv
# User lenght :  3797
# Correct :  72
# Incorrect :  557
# Undefined :  41
# User short days :  10
# Accuracy :  0.09473684210526316
# ======================================================================================================
# User :  003065be0615.log.mv
# User lenght :  1110
# Correct :  101
# Incorrect :  52
# Undefined :  33
# User short days :  3
# Accuracy :  0.45495495495495497
# ======================================================================================================
# User :  004096b28975.log.mv
# User lenght :  1485
# Correct :  48
# Incorrect :  213
# Undefined :  15
# User short days :  2
# Accuracy :  0.16161616161616163
# ======================================================================================================
# User :  003065b4c085.log.mv
# User lenght :  9700
# Correct :  509
# Incorrect :  912
# Undefined :  435
# User short days :  1
# Accuracy :  0.26237113402061857
# ======================================================================================================
# User :  080046a567a5.log.mv
# User lenght :  1547
# Correct :  148
# Incorrect :  123
# Undefined :  15
# User short days :  0
# Accuracy :  0.4774193548387097
# ======================================================================================================
# User :  004096d86545.log.mv
# User lenght :  8892
# Correct :  771
# Incorrect :  942
# Undefined :  0
# User short days :  0
# Accuracy :  0.433389544688027
# ======================================================================================================
# User :  00409686bf25.log.mv
# User lenght :  3224
# Correct :  385
# Incorrect :  223
# Undefined :  11
# User short days :  0
# Accuracy :  0.5968992248062015
# ======================================================================================================
# User :  00022d358176.log.mv
# User lenght :  1709
# Correct :  69
# Incorrect :  136
# Undefined :  93
# User short days :  10
# Accuracy :  0.20175438596491227
# ======================================================================================================
# User :  00022d3ed216.log.mv
# User lenght :  1882
# Correct :  162
# Incorrect :  156
# Undefined :  21
# User short days :  3
# Accuracy :  0.4297082228116711
# ======================================================================================================
# User :  00022d359b86.log.mv
# User lenght :  67280
# Correct :  10117
# Incorrect :  3209
# Undefined :  88
# User short days :  0
# Accuracy :  0.75185790725327
# ======================================================================================================
# User :  00022d206286.log.mv
# User lenght :  29339
# Correct :  4929
# Incorrect :  42
# Undefined :  712
# User short days :  3
# Accuracy :  0.8399795501022495
# ======================================================================================================
# User :  00022d234446.log.mv
# User lenght :  1597
# Correct :  200
# Incorrect :  76
# Undefined :  12
# User short days :  1
# Accuracy :  0.625
# ======================================================================================================
# User :  00022d20f446.log.mv
# User lenght :  4577
# Correct :  607
# Incorrect :  272
# Undefined :  15
# User short days :  0
# Accuracy :  0.6626637554585153
# ======================================================================================================
# User :  00022d17a6d6.log.mv
# User lenght :  1202
# Correct :  175
# Incorrect :  10
# Undefined :  27
# User short days :  0
# Accuracy :  0.7261410788381742
# ======================================================================================================
# User :  00022d44cfd6.log.mv
# User lenght :  1553
# Correct :  75
# Incorrect :  115
# Undefined :  66
# User short days :  1
# Accuracy :  0.24115755627009647
# ======================================================================================================
# User :  00022d0bd5b6.log.mv
# User lenght :  1115
# Correct :  43
# Incorrect :  94
# Undefined :  47
# User short days :  14
# Accuracy :  0.19282511210762332
# ======================================================================================================
# User :  00022d203896.log.mv
# User lenght :  1522
# Correct :  126
# Incorrect :  127
# Undefined :  9
# User short days :  5
# Accuracy :  0.4131147540983607
# ======================================================================================================
# User :  00022d00c776.log.mv
# User lenght :  3023
# Correct :  224
# Incorrect :  329
# Undefined :  29
# User short days :  1
# Accuracy :  0.3702479338842975
# ======================================================================================================
# User :  00022d0cdc36.log.mv
# User lenght :  3630
# Correct :  716
# Incorrect :  0
# Undefined :  0
# User short days :  0
# Accuracy :  0.9862258953168044
# ======================================================================================================
# User :  00022d10ab86.log.mv
# User lenght :  5428
# Correct :  507
# Incorrect :  333
# Undefined :  200
# User short days :  0
# Accuracy :  0.46685082872928174
# ======================================================================================================
# User :  00022d3fd2f6.log.mv
# User lenght :  1600
# Correct :  174
# Incorrect :  122
# Undefined :  0
# User short days :  0
# Accuracy :  0.54375
# ======================================================================================================
# User :  00022d0c3b96.log.mv
# User lenght :  1099
# Correct :  85
# Incorrect :  65
# Undefined :  38
# User short days :  1
# Accuracy :  0.38636363636363635
# ======================================================================================================
# User :  00022d2997c6.log.mv
# User lenght :  1043
# Correct :  10
# Incorrect :  41
# Undefined :  141
# User short days :  0
# Accuracy :  0.04784688995215311
# ======================================================================================================
# User :  00022d2a7f36.log.mv
# User lenght :  1058
# Correct :  55
# Incorrect :  53
# Undefined :  87
# User short days :  1
# Accuracy :  0.25943396226415094
# ======================================================================================================
# User :  00022d207e46.log.mv
# User lenght :  10806
# Correct :  1289
# Incorrect :  791
# Undefined :  39
# User short days :  7
# Accuracy :  0.5962072155411656
# ======================================================================================================
# User :  00022d0c1e26.log.mv
# User lenght :  2548
# Correct :  229
# Incorrect :  116
# Undefined :  118
# User short days :  0
# Accuracy :  0.44901960784313727
# ======================================================================================================
# User :  00022d52e056.log.mv
# User lenght :  2487
# Correct :  85
# Incorrect :  228
# Undefined :  123
# User short days :  3
# Accuracy :  0.1706827309236948
# ======================================================================================================
# User :  00022d781236.log.mv
# User lenght :  1820
# Correct :  167
# Incorrect :  153
# Undefined :  20
# User short days :  1
# Accuracy :  0.45879120879120877
# ======================================================================================================
# User :  00022d45d446.log.mv
# User lenght :  3673
# Correct :  317
# Incorrect :  383
# Undefined :  3
# User short days :  1
# Accuracy :  0.4312925170068027
# ======================================================================================================
# User :  00022da9f8f6.log.mv
# User lenght :  7995
# Correct :  290
# Incorrect :  1102
# Undefined :  59
# User short days :  2
# Accuracy :  0.1813633520950594
# ======================================================================================================
# User :  00022d9a88d6.log.mv
# User lenght :  2671
# Correct :  366
# Incorrect :  84
# Undefined :  32
# User short days :  7
# Accuracy :  0.6841121495327103
# ======================================================================================================
# User :  00022d690a66.log.mv
# User lenght :  2272
# Correct :  151
# Incorrect :  247
# Undefined :  28
# User short days :  0
# Accuracy :  0.33186813186813185
# ======================================================================================================
# User :  00022d7d4e46.log.mv
# User lenght :  3518
# Correct :  435
# Incorrect :  211
# Undefined :  28
# User short days :  1
# Accuracy :  0.6178977272727273
# ======================================================================================================
# User :  00022d7ff066.log.mv
# User lenght :  5998
# Correct :  447
# Incorrect :  741
# Undefined :  6
# User short days :  0
# Accuracy :  0.3725
# ======================================================================================================
# User :  00022da4f596.log.mv
# User lenght :  1777
# Correct :  39
# Incorrect :  146
# Undefined :  55
# User short days :  7
# Accuracy :  0.10955056179775281
# ======================================================================================================
# User :  00022dae4796.log.mv
# User lenght :  2568
# Correct :  160
# Incorrect :  227
# Undefined :  76
# User short days :  7
# Accuracy :  0.311284046692607
# ======================================================================================================
# User :  00022d981326.log.mv
# User lenght :  1853
# Correct :  18
# Incorrect :  148
# Undefined :  78
# User short days :  8
# Accuracy :  0.04851752021563342
# ======================================================================================================
# User :  00022da0c576.log.mv
# User lenght :  1667
# Correct :  31
# Incorrect :  226
# Undefined :  41
# User short days :  5
# Accuracy :  0.09281437125748503
# ======================================================================================================
# User :  00022dacc066.log.mv
# User lenght :  1223
# Correct :  124
# Incorrect :  113
# Undefined :  0
# User short days :  0
# Accuracy :  0.5061224489795918
# ======================================================================================================
# User :  00022d4cadb6.log.mv
# User lenght :  2466
# Correct :  407
# Incorrect :  56
# Undefined :  0
# User short days :  0
# Accuracy :  0.8238866396761133
# ======================================================================================================
# User :  00022d8b79e6.log.mv
# User lenght :  1220
# Correct :  53
# Incorrect :  99
# Undefined :  78
# User short days :  1
# Accuracy :  0.21721311475409835
# ======================================================================================================
# User :  00022d5a42d6.log.mv
# User lenght :  12319
# Correct :  1282
# Incorrect :  674
# Undefined :  436
# User short days :  1
# Accuracy :  0.5202922077922078
# ======================================================================================================
# User :  00022d790ea6.log.mv
# User lenght :  1997
# Correct :  261
# Incorrect :  126
# Undefined :  0
# User short days :  0
# Accuracy :  0.6525
# ======================================================================================================
# User :  00022db0af76.log.mv
# User lenght :  28650
# Correct :  4349
# Incorrect :  1292
# Undefined :  34
# User short days :  5
# Accuracy :  0.7589877835951134
# ======================================================================================================
# User :  00022d997cb6.log.mv
# User lenght :  3791
# Correct :  400
# Incorrect :  318
# Undefined :  1
# User short days :  0
# Accuracy :  0.5270092226613966
# ======================================================================================================
# User :  00022d987006.log.mv
# User lenght :  11785
# Correct :  1427
# Incorrect :  917
# Undefined :  0
# User short days :  0
# Accuracy :  0.6054306321595249
# ======================================================================================================
# User :  00022dbcef66.log.mv
# User lenght :  11755
# Correct :  1780
# Incorrect :  548
# Undefined :  1
# User short days :  0
# Accuracy :  0.7571246278179498
# ======================================================================================================
# User :  00022df623b6.log.mv
# User lenght :  1668
# Correct :  86
# Incorrect :  191
# Undefined :  4
# User short days :  1
# Accuracy :  0.25748502994011974
# ======================================================================================================
# User :  00022dedee16.log.mv
# User lenght :  4229
# Correct :  481
# Incorrect :  275
# Undefined :  57
# User short days :  2
# Accuracy :  0.5685579196217494
# ======================================================================================================
# User :  00022dc27526.log.mv
# User lenght :  20082
# Correct :  3411
# Incorrect :  565
# Undefined :  9
# User short days :  0
# Accuracy :  0.8491411501120238
# ======================================================================================================
# User :  00022dc32046.log.mv
# User lenght :  1542
# Correct :  120
# Incorrect :  109
# Undefined :  42
# User short days :  5
# Accuracy :  0.3883495145631068
# ======================================================================================================
# User :  00022df53536.log.mv
# User lenght :  2218
# Correct :  80
# Incorrect :  297
# Undefined :  49
# User short days :  3
# Accuracy :  0.18018018018018017
# ======================================================================================================
# User :  00022dc7bc36.log.mv
# User lenght :  15813
# Correct :  2232
# Incorrect :  920
# Undefined :  0
# User short days :  0
# Accuracy :  0.7056591843186848
# ======================================================================================================
# User :  00022dc5bee6.log.mv
# User lenght :  1177
# Correct :  135
# Incorrect :  51
# Undefined :  35
# User short days :  2
# Accuracy :  0.5720338983050848
# ======================================================================================================
# User :  00022deefdf6.log.mv
# User lenght :  8283
# Correct :  1509
# Incorrect :  117
# Undefined :  0
# User short days :  0
# Accuracy :  0.9106819553409776
# ======================================================================================================
# User :  00022dbc98a6.log.mv
# User lenght :  2553
# Correct :  195
# Incorrect :  263
# Undefined :  8
# User short days :  2
# Accuracy :  0.3816046966731898
# ======================================================================================================
# User :  00022ddd1706.log.mv
# User lenght :  7463
# Correct :  960
# Incorrect :  504
# Undefined :  3
# User short days :  0
# Accuracy :  0.6430006697923644
# ======================================================================================================
# User :  00022df12826.log.mv
# User lenght :  5816
# Correct :  979
# Incorrect :  117
# Undefined :  5
# User short days :  5
# Accuracy :  0.8410652920962199
# ======================================================================================================
# User :  00022dc20c36.log.mv
# User lenght :  2909
# Correct :  170
# Incorrect :  334
# Undefined :  32
# User short days :  6
# Accuracy :  0.2920962199312715
# ======================================================================================================
# User :  00022de0ca86.log.mv
# User lenght :  2150
# Correct :  123
# Incorrect :  123
# Undefined :  122
# User short days :  7
# Accuracy :  0.28604651162790695
# ======================================================================================================
# User :  00022dd99cc6.log.mv
# User lenght :  1030
# Correct :  30
# Incorrect :  93
# Undefined :  42
# User short days :  7
# Accuracy :  0.14563106796116504
# ======================================================================================================
# User :  0006255c9046.log.mv
# User lenght :  1637
# Correct :  145
# Incorrect :  145
# Undefined :  21
# User short days :  1
# Accuracy :  0.4420731707317073
# ======================================================================================================
# User :  00045a4f11e6.log.mv
# User lenght :  3389
# Correct :  175
# Incorrect :  260
# Undefined :  214
# User short days :  4
# Accuracy :  0.2581120943952802
# ======================================================================================================
# User :  00053cb0c616.log.mv
# User lenght :  2533
# Correct :  263
# Incorrect :  214
# Undefined :  4
# User short days :  2
# Accuracy :  0.5187376725838264
# ======================================================================================================
# User :  00053c8c0216.log.mv
# User lenght :  3189
# Correct :  391
# Incorrect :  229
# Undefined :  1
# User short days :  1
# Accuracy :  0.6128526645768025
# ======================================================================================================
# User :  00055d3f9e36.log.mv
# User lenght :  9400
# Correct :  126
# Incorrect :  1622
# Undefined :  119
# User short days :  0
# Accuracy :  0.06702127659574468
# ======================================================================================================
# User :  000625be4896.log.mv
# User lenght :  2683
# Correct :  528
# Incorrect :  2
# Undefined :  0
# User short days :  0
# Accuracy :  0.9832402234636871
# ======================================================================================================
# User :  00062554a2f6.log.mv
# User lenght :  3743
# Correct :  747
# Incorrect :  1
# Undefined :  0
# User short days :  0
# Accuracy :  0.9973297730307076
# ======================================================================================================
# User :  00022dfb6716.log.mv
# User lenght :  3496
# Correct :  167
# Incorrect :  439
# Undefined :  36
# User short days :  10
# Accuracy :  0.23857142857142857
# ======================================================================================================
# User :  00070e0da676.log.mv
# User lenght :  1196
# Correct :  42
# Incorrect :  173
# Undefined :  3
# User short days :  2
# Accuracy :  0.175
# ======================================================================================================
# User :  00053c7d1536.log.mv
# User lenght :  1491
# Correct :  63
# Incorrect :  169
# Undefined :  18
# User short days :  6
# Accuracy :  0.21070234113712374
# ======================================================================================================
# User :  00053c95aa46.log.mv
# User lenght :  38649
# Correct :  5467
# Incorrect :  2191
# Undefined :  28
# User short days :  0
# Accuracy :  0.7072445019404916
# ======================================================================================================
# User :  0002b38e4a86.log.mv
# User lenght :  9016
# Correct :  569
# Incorrect :  118
# Undefined :  1083
# User short days :  4
# Accuracy :  0.31541019955654104
# ======================================================================================================
# User :  00053c575656.log.mv
# User lenght :  1033
# Correct :  23
# Incorrect :  132
# Undefined :  23
# User short days :  9
# Accuracy :  0.1111111111111111
# ======================================================================================================
# User :  000625daa8c6.log.mv
# User lenght :  1155
# Correct :  91
# Incorrect :  136
# Undefined :  1
# User short days :  1
# Accuracy :  0.3939393939393939
# ======================================================================================================
# User :  000625e5b056.log.mv
# User lenght :  10903
# Correct :  831
# Incorrect :  904
# Undefined :  421
# User short days :  1
# Accuracy :  0.3810178817056396
# ======================================================================================================
# User :  00053c78fdf6.log.mv
# User lenght :  2844
# Correct :  393
# Incorrect :  153
# Undefined :  0
# User short days :  0
# Accuracy :  0.6906854130052724
# ======================================================================================================
# User :  00070e0ec886.log.mv
# User lenght :  29363
# Correct :  1429
# Incorrect :  1798
# Undefined :  2587
# User short days :  2
# Accuracy :  0.24331687382938874
# ======================================================================================================
# User :  0009b76a32c6.log.mv
# User lenght :  24275
# Correct :  2215
# Incorrect :  2633
# Undefined :  0
# User short days :  0
# Accuracy :  0.45623069001029865
# ======================================================================================================
# User :  003065294706.log.mv
# User lenght :  1295
# Correct :  144
# Incorrect :  53
# Undefined :  4
# User short days :  4
# Accuracy :  0.555984555984556
# ======================================================================================================
# User :  0030652e6796.log.mv
# User lenght :  1052
# Correct :  179
# Incorrect :  3
# Undefined :  9
# User short days :  9
# Accuracy :  0.8483412322274881
# ======================================================================================================
# User :  00070e7040c6.log.mv
# User lenght :  2066
# Correct :  88
# Incorrect :  268
# Undefined :  5
# User short days :  1
# Accuracy :  0.21256038647342995
# ======================================================================================================
# User :  0030651d9fe6.log.mv
# User lenght :  10732
# Correct :  1784
# Incorrect :  79
# Undefined :  232
# User short days :  7
# Accuracy :  0.8309268747088961
# ======================================================================================================
# User :  003065309e46.log.mv
# User lenght :  1828
# Correct :  256
# Incorrect :  61
# Undefined :  18
# User short days :  0
# Accuracy :  0.6994535519125683
# ======================================================================================================
# User :  000af4ba4a96.log.mv
# User lenght :  1920
# Correct :  194
# Incorrect :  173
# Undefined :  7
# User short days :  2
# Accuracy :  0.5052083333333334
# ======================================================================================================
# User :  000a8a45e0c6.log.mv
# User lenght :  1943
# Correct :  225
# Incorrect :  151
# Undefined :  0
# User short days :  0
# Accuracy :  0.5784061696658098
# ======================================================================================================
# User :  00070ea71ad6.log.mv
# User lenght :  1753
# Correct :  19
# Incorrect :  320
# Undefined :  1
# User short days :  1
# Accuracy :  0.05413105413105413
# ======================================================================================================
# User :  00306542b676.log.mv
# User lenght :  1032
# Correct :  86
# Incorrect :  38
# Undefined :  10
# User short days :  10
# Accuracy :  0.41545893719806765
# ======================================================================================================
# User :  0020e0e040c6.log.mv
# User lenght :  4694
# Correct :  435
# Incorrect :  447
# Undefined :  22
# User short days :  5
# Accuracy :  0.46325878594249204
# ======================================================================================================
# User :  003065239f46.log.mv
# User lenght :  3787
# Correct :  443
# Incorrect :  140
# Undefined :  30
# User short days :  23
# Accuracy :  0.5844327176781002
# ======================================================================================================
# User :  00070e96ba46.log.mv
# User lenght :  2615
# Correct :  252
# Incorrect :  209
# Undefined :  29
# User short days :  3
# Accuracy :  0.4818355640535373
# ======================================================================================================
# User :  000ab74d7a36.log.mv
# User lenght :  1989
# Correct :  280
# Incorrect :  67
# Undefined :  13
# User short days :  0
# Accuracy :  0.7035175879396985
# ======================================================================================================
# User :  000a4189d756.log.mv
# User lenght :  2713
# Correct :  313
# Incorrect :  192
# Undefined :  0
# User short days :  0
# Accuracy :  0.576427255985267
# ======================================================================================================
# User :  0030651794b6.log.mv
# User lenght :  2112
# Correct :  65
# Incorrect :  237
# Undefined :  69
# User short days :  0
# Accuracy :  0.1536643026004728
# ======================================================================================================
# User :  00070e195da6.log.mv
# User lenght :  6184
# Correct :  538
# Incorrect :  358
# Undefined :  268
# User short days :  2
# Accuracy :  0.4349232012934519
# ======================================================================================================
# User :  0030650e7e96.log.mv
# User lenght :  1273
# Correct :  166
# Incorrect :  34
# Undefined :  23
# User short days :  0
# Accuracy :  0.6509803921568628
# ======================================================================================================
# User :  000a8a6cb9d6.log.mv
# User lenght :  3486
# Correct :  479
# Incorrect :  198
# Undefined :  1
# User short days :  0
# Accuracy :  0.6862464183381088
# ======================================================================================================
# User :  0030653dfa36.log.mv
# User lenght :  3060
# Correct :  48
# Incorrect :  362
# Undefined :  162
# User short days :  1
# Accuracy :  0.0784313725490196
# ======================================================================================================
# User :  0030651e6b26.log.mv
# User lenght :  4851
# Correct :  398
# Incorrect :  327
# Undefined :  172
# User short days :  2
# Accuracy :  0.4098867147270855
# ======================================================================================================
# User :  00070ee42b16.log.mv
# User lenght :  1507
# Correct :  86
# Incorrect :  168
# Undefined :  4
# User short days :  1
# Accuracy :  0.2847682119205298
# ======================================================================================================
# User :  0030653a6e46.log.mv
# User lenght :  1620
# Correct :  191
# Incorrect :  111
# Undefined :  1
# User short days :  0
# Accuracy :  0.5895061728395061
# ======================================================================================================
# User :  0030656c5016.log.mv
# User lenght :  6488
# Correct :  558
# Incorrect :  646
# Undefined :  22
# User short days :  0
# Accuracy :  0.42989214175654855
# ======================================================================================================
# User :  003065d15da6.log.mv
# User lenght :  1912
# Correct :  68
# Incorrect :  186
# Undefined :  32
# User short days :  3
# Accuracy :  0.17754569190600522
# ======================================================================================================
# User :  003065ba6446.log.mv
# User lenght :  2318
# Correct :  10
# Incorrect :  140
# Undefined :  267
# User short days :  3
# Accuracy :  0.021551724137931036
# ======================================================================================================
# User :  003065a48406.log.mv
# User lenght :  2050
# Correct :  280
# Incorrect :  46
# Undefined :  5
# User short days :  2
# Accuracy :  0.6829268292682927
# ======================================================================================================
# User :  0030657c51b6.log.mv
# User lenght :  3916
# Correct :  129
# Incorrect :  541
# Undefined :  43
# User short days :  3
# Accuracy :  0.16454081632653061
# ======================================================================================================
# User :  003065de1216.log.mv
# User lenght :  1571
# Correct :  116
# Incorrect :  145
# Undefined :  29
# User short days :  1
# Accuracy :  0.3682539682539683
# ======================================================================================================
# User :  0030657c49b6.log.mv
# User lenght :  4336
# Correct :  587
# Incorrect :  238
# Undefined :  5
# User short days :  0
# Accuracy :  0.6762672811059908
# ======================================================================================================
# User :  0030655123d6.log.mv
# User lenght :  2030
# Correct :  208
# Incorrect :  191
# Undefined :  0
# User short days :  0
# Accuracy :  0.5123152709359606
# ======================================================================================================
# User :  003065a9c4a6.log.mv
# User lenght :  1055
# Correct :  170
# Incorrect :  16
# Undefined :  0
# User short days :  0
# Accuracy :  0.8056872037914692
# ======================================================================================================
# User :  0030658b46f6.log.mv
# User lenght :  1963
# Correct :  87
# Incorrect :  233
# Undefined :  6
# User short days :  0
# Accuracy :  0.22137404580152673
# ======================================================================================================
# User :  003065bebdb6.log.mv
# User lenght :  1636
# Correct :  98
# Incorrect :  115
# Undefined :  62
# User short days :  0
# Accuracy :  0.29878048780487804
# ======================================================================================================
# User :  0030657dfb86.log.mv
# User lenght :  1705
# Correct :  193
# Incorrect :  111
# Undefined :  8
# User short days :  0
# Accuracy :  0.5659824046920822
# ======================================================================================================
# User :  003065929526.log.mv
# User lenght :  1945
# Correct :  151
# Incorrect :  172
# Undefined :  18
# User short days :  2
# Accuracy :  0.38817480719794345
# ======================================================================================================
# User :  0030659ff646.log.mv
# User lenght :  2691
# Correct :  6
# Incorrect :  220
# Undefined :  236
# User short days :  10
# Accuracy :  0.011131725417439703
# ======================================================================================================
# User :  0030655b77a6.log.mv
# User lenght :  1349
# Correct :  75
# Incorrect :  108
# Undefined :  49
# User short days :  5
# Accuracy :  0.2777777777777778
# ======================================================================================================
# User :  003065b24ed6.log.mv
# User lenght :  3025
# Correct :  322
# Incorrect :  257
# Undefined :  1
# User short days :  0
# Accuracy :  0.5322314049586777
# ======================================================================================================
# User :  00306528bac1.log.mv
# User lenght :  1665
# Correct :  143
# Incorrect :  117
# Undefined :  0
# User short days :  0
# Accuracy :  0.4294294294294294
# ======================================================================================================
# User :  000ab7771501.log.mv
# User lenght :  11038
# Correct :  1274
# Incorrect :  899
# Undefined :  0
# User short days :  0
# Accuracy :  0.5769927536231884
# ======================================================================================================
# User :  000ab71a8381.log.mv
# User lenght :  1735
# Correct :  91
# Incorrect :  241
# Undefined :  1
# User short days :  1
# Accuracy :  0.2622478386167147
# ======================================================================================================
# User :  0009b7cc7c41.log.mv
# User lenght :  6195
# Correct :  741
# Incorrect :  461
# Undefined :  18
# User short days :  0
# Accuracy :  0.5980629539951574
# ======================================================================================================
# User :  0030650c0321.log.mv
# User lenght :  4943
# Correct :  634
# Incorrect :  323
# Undefined :  1
# User short days :  1
# Accuracy :  0.641051567239636
# ======================================================================================================
# User :  000af4158581.log.mv
# User lenght :  8044
# Correct :  914
# Incorrect :  664
# Undefined :  20
# User short days :  0
# Accuracy :  0.5680546923555003
# ======================================================================================================
# User :  0030651dafd1.log.mv
# User lenght :  7751
# Correct :  1025
# Incorrect :  401
# Undefined :  63
# User short days :  3
# Accuracy :  0.6608639587362991
# ======================================================================================================
# User :  003065366a61.log.mv
# User lenght :  7240
# Correct :  662
# Incorrect :  655
# Undefined :  18
# User short days :  0
# Accuracy :  0.457182320441989
# ======================================================================================================
# User :  0030659cc9b1.log.mv
# User lenght :  4612
# Correct :  414
# Incorrect :  450
# Undefined :  0
# User short days :  0
# Accuracy :  0.4485373781148429
# ======================================================================================================
# User :  003065b6cd91.log.mv
# User lenght :  2111
# Correct :  174
# Incorrect :  172
# Undefined :  12
# User short days :  3
# Accuracy :  0.41134751773049644
# ======================================================================================================
# User :  0030654b8551.log.mv
# User lenght :  1480
# Correct :  197
# Incorrect :  70
# Undefined :  1
# User short days :  1
# Accuracy :  0.6655405405405406
# ======================================================================================================
# User :  0030655f6c81.log.mv
# User lenght :  1267
# Correct :  79
# Incorrect :  167
# Undefined :  2
# User short days :  0
# Accuracy :  0.3110236220472441
# ======================================================================================================
# User :  00306589f331.log.mv
# User lenght :  4029
# Correct :  394
# Incorrect :  263
# Undefined :  88
# User short days :  1
# Accuracy :  0.48883374689826303
# ======================================================================================================
# User :  003065afe4d1.log.mv
# User lenght :  1443
# Correct :  107
# Incorrect :  146
# Undefined :  11
# User short days :  0
# Accuracy :  0.370242214532872
# ======================================================================================================
# User :  003065ae0321.log.mv
# User lenght :  6705
# Correct :  711
# Incorrect :  539
# Undefined :  27
# User short days :  0
# Accuracy :  0.5302013422818792
# ======================================================================================================
# User :  003065e8b691.log.mv
# User lenght :  2627
# Correct :  499
# Incorrect :  20
# Undefined :  0
# User short days :  0
# Accuracy :  0.9486692015209125
# ======================================================================================================
# User :  003065b312a1.log.mv
# User lenght :  1062
# Correct :  126
# Incorrect :  67
# Undefined :  1
# ...
# Correct :  112
# Incorrect :  182
# Undefined :  25
# User short days :  1
# Accuracy :  0.3154929577464789
# ======================================================================================================
# User :  00022d468591.log.mv
# User lenght :  1957
# Correct :  151
# Incorrect :  129
# Undefined :  89
# User short days :  0
# Accuracy :  0.3852040816326531
# ======================================================================================================
# User :  00022d3c5ba1.log.mv
# User lenght :  30366
# Correct :  2335
# Incorrect :  2334
# Undefined :  1229
# User short days :  5
# Accuracy :  0.38442541982219297
# ======================================================================================================
# User :  00022d540de1.log.mv
# User lenght :  5276
# Correct :  584
# Incorrect :  317
# Undefined :  78
# User short days :  18
# Accuracy :  0.553030303030303
# ======================================================================================================
# User :  00022d4887e1.log.mv
# User lenght :  2648
# Correct :  348
# Incorrect :  168
# Undefined :  0
# User short days :  0
# Accuracy :  0.6566037735849056
# ======================================================================================================
# User :  00022d5895d1.log.mv
# User lenght :  1223
# Correct :  131
# Incorrect :  60
# Undefined :  29
# User short days :  1
# Accuracy :  0.5346938775510204
# ======================================================================================================
# User :  00022d4364d1.log.mv
# User lenght :  2992
# Correct :  222
# Incorrect :  151
# Undefined :  196
# User short days :  1
# Accuracy :  0.37061769616026713
# ======================================================================================================
# User :  00022d3cb851.log.mv
# User lenght :  2286
# Correct :  305
# Incorrect :  147
# Undefined :  1
# User short days :  0
# Accuracy :  0.665938864628821
# ======================================================================================================
# User :  00022d5a4d11.log.mv
# User lenght :  1314
# Correct :  69
# Incorrect :  102
# Undefined :  45
# User short days :  8
# Accuracy :  0.2623574144486692
# ======================================================================================================
# User :  00022d5f5601.log.mv
# User lenght :  1945
# Correct :  302
# Incorrect :  61
# Undefined :  1
# User short days :  0
# Accuracy :  0.7763496143958869
# ======================================================================================================
# User :  00022d423741.log.mv
# User lenght :  3138
# Correct :  171
# Incorrect :  323
# Undefined :  122
# User short days :  0
# Accuracy :  0.27229299363057324
# ======================================================================================================
# User :  00022d684ae1.log.mv
# User lenght :  3415
# Correct :  170
# Incorrect :  372
# Undefined :  111
# User short days :  1
# Accuracy :  0.24890190336749635
# ======================================================================================================
# User :  00022dc7ac01.log.mv
# User lenght :  11410
# Correct :  1787
# Incorrect :  344
# Undefined :  32
# User short days :  4
# Accuracy :  0.7830850131463628
# ======================================================================================================
# User :  00022dbc0cd1.log.mv
# User lenght :  1015
# Correct :  40
# Incorrect :  112
# Undefined :  16
# User short days :  4
# Accuracy :  0.19704433497536947
# ======================================================================================================
# User :  00022dd6da91.log.mv
# User lenght :  2863
# Correct :  57
# Incorrect :  229
# Undefined :  146
# User short days :  15
# Accuracy :  0.09947643979057591
# ======================================================================================================
# User :  00022d906b31.log.mv
# User lenght :  1179
# Correct :  32
# Incorrect :  107
# Undefined :  56
# User short days :  17
# Accuracy :  0.13559322033898305
# ======================================================================================================
# User :  00022d9ee361.log.mv
# User lenght :  1340
# Correct :  186
# Incorrect :  37
# Undefined :  10
# User short days :  3
# Accuracy :  0.6940298507462687
# ======================================================================================================
# User :  00022d70f651.log.mv
# User lenght :  13295
# Correct :  1786
# Incorrect :  829
# Undefined :  18
# User short days :  0
# Accuracy :  0.6716810831139526
# ======================================================================================================
# User :  00022dc486c1.log.mv
# User lenght :  1061
# Correct :  64
# Incorrect :  75
# Undefined :  47
# User short days :  5
# Accuracy :  0.3004694835680751
# ======================================================================================================
# User :  00022dc76dc1.log.mv
# User lenght :  1446
# Correct :  56
# Incorrect :  196
# Undefined :  4
# User short days :  0
# Accuracy :  0.19310344827586207
# ======================================================================================================
# User :  00022dba8f51.log.mv
# User lenght :  34723
# Correct :  4714
# Incorrect :  2053
# Undefined :  147
# User short days :  0
# Accuracy :  0.6787616990640749
# ======================================================================================================
# User :  00022da80931.log.mv
# User lenght :  1208
# Correct :  125
# Incorrect :  90
# Undefined :  10
# User short days :  1
# Accuracy :  0.5165289256198347
# ======================================================================================================
# User :  00022d9300d1.log.mv
# User lenght :  1722
# Correct :  209
# Incorrect :  79
# Undefined :  19
# User short days :  1
# Accuracy :  0.6057971014492753
# ======================================================================================================
# User :  00022dc1a961.log.mv
# User lenght :  4327
# Correct :  752
# Incorrect :  59
# Undefined :  32
# User short days :  0
# Accuracy :  0.8683602771362586
# ======================================================================================================
# User :  00022d9f4221.log.mv
# User lenght :  1844
# Correct :  125
# Incorrect :  146
# Undefined :  6
# User short days :  4
# Accuracy :  0.33875338753387535
# ======================================================================================================
# User :  00022d89bdd1.log.mv
# User lenght :  1496
# Correct :  176
# Incorrect :  108
# Undefined :  1
# User short days :  0
# Accuracy :  0.5866666666666667
# ======================================================================================================
# User :  00022d707241.log.mv
# User lenght :  7429
# Correct :  1197
# Incorrect :  225
# Undefined :  41
# User short days :  0
# Accuracy :  0.8055181695827726
# ======================================================================================================
# User :  00022dc97ab1.log.mv
# User lenght :  1598
# Correct :  174
# Incorrect :  122
# Undefined :  15
# User short days :  0
# Accuracy :  0.54375
# ======================================================================================================
# User :  00022d9a2e21.log.mv
# User lenght :  1634
# Correct :  77
# Incorrect :  158
# Undefined :  35
# User short days :  25
# Accuracy :  0.23547400611620795
# ======================================================================================================
# User :  00022d8d7351.log.mv
# User lenght :  18042
# Correct :  3057
# Incorrect :  529
# Undefined :  0
# User short days :  0
# Accuracy :  0.8470490440565254
# ======================================================================================================
# User :  00022d8272f1.log.mv
# User lenght :  1266
# Correct :  218
# Incorrect :  22
# Undefined :  0
# User short days :  0
# Accuracy :  0.8582677165354331
# ======================================================================================================
# User :  00022dbffcb1.log.mv
# User lenght :  2641
# Correct :  278
# Incorrect :  194
# Undefined :  39
# User short days :  0
# Accuracy :  0.5255198487712666
# ======================================================================================================
# User :  00022daaf3d1.log.mv
# User lenght :  1667
# Correct :  163
# Incorrect :  109
# Undefined :  40
# User short days :  0
# Accuracy :  0.4880239520958084
# ======================================================================================================
# User :  00022de1c6c1.log.mv
# User lenght :  1437
# Correct :  221
# Incorrect :  24
# Undefined :  11
# User short days :  0
# Accuracy :  0.7673611111111112
# ======================================================================================================
# User :  00022dfdfb31.log.mv
# User lenght :  1914
# Correct :  223
# Incorrect :  114
# Undefined :  5
# User short days :  1
# Accuracy :  0.5822454308093995
# ======================================================================================================
# User :  00070e693f11.log.mv
# User lenght :  2274
# Correct :  277
# Incorrect :  176
# Undefined :  0
# User short days :  0
# Accuracy :  0.6087912087912087
# ======================================================================================================
# User :  00070ebde5d1.log.mv
# User lenght :  2120
# Correct :  113
# Incorrect :  264
# Undefined :  1
# User short days :  1
# Accuracy :  0.2665094339622642
# ======================================================================================================
# User :  00032f6d92b1 (1).log.mv
# User lenght :  6806
# Correct :  1099
# Incorrect :  212
# Undefined :  20
# User short days :  2
# Accuracy :  0.8069016152716594
# ======================================================================================================
# User :  00070eb92ba1.log.mv
# User lenght :  1286
# Correct :  62
# Incorrect :  140
# Undefined :  14
# User short days :  2
# Accuracy :  0.24031007751937986
# ======================================================================================================
# User :  000821f0dc31.log.mv
# User lenght :  1050
# Correct :  110
# Incorrect :  59
# Undefined :  14
# User short days :  6
# Accuracy :  0.5238095238095238
# ======================================================================================================
# User :  00070e27c4f1.log.mv
# User lenght :  1815
# Correct :  150
# Incorrect :  147
# Undefined :  6
# User short days :  6
# Accuracy :  0.4132231404958678
# ======================================================================================================
# User :  00070ec8fba1.log.mv
# User lenght :  2567
# Correct :  119
# Incorrect :  324
# Undefined :  19
# User short days :  8
# Accuracy :  0.23151750972762647
# ======================================================================================================
# User :  00053c438691.log.mv
# User lenght :  1172
# Correct :  75
# Incorrect :  109
# Undefined :  5
# User short days :  5
# Accuracy :  0.3191489361702128
# ======================================================================================================
# User :  00032f6d92b1.log.mv
# User lenght :  6806
# Correct :  1099
# Incorrect :  212
# Undefined :  20
# User short days :  2
# Accuracy :  0.8069016152716594
# ======================================================================================================
# User :  0006257ec9f1.log.mv
# User lenght :  16846
# Correct :  2412
# Incorrect :  937
# Undefined :  0
# User short days :  0
# Accuracy :  0.715727002967359
# ======================================================================================================
# User :  00022de96771.log.mv
# User lenght :  1314
# Correct :  176
# Incorrect :  46
# Undefined :  0
# User short days :  0
# Accuracy :  0.6692015209125475
# ======================================================================================================
# User :  00032f5418f1.log.mv
# User lenght :  3648
# Correct :  720
# Incorrect :  6
# Undefined :  1
# User short days :  0
# Accuracy :  0.9863013698630136
# ======================================================================================================
# User :  0007eba03671.log.mv
# User lenght :  2088
# Correct :  111
# Incorrect :  260
# Undefined :  8
# User short days :  0
# Accuracy :  0.26555023923444976
# ======================================================================================================
# User :  00032f98cf71.log.mv
# User lenght :  5081
# Correct :  334
# Incorrect :  557
# Undefined :  93
# User short days :  7
# Accuracy :  0.32841691248770893
# ======================================================================================================
# User :  0009b7a067c1.log.mv
# User lenght :  2038
# Correct :  145
# Incorrect :  207
# Undefined :  19
# User short days :  0
# Accuracy :  0.3553921568627451
# ======================================================================================================
# User :  00022de10371.log.mv
# User lenght :  1665
# Correct :  219
# Incorrect :  64
# Undefined :  30
# User short days :  0
# Accuracy :  0.6576576576576577
# ======================================================================================================
# User :  00053c81ed11.log.mv
# User lenght :  1313
# Correct :  109
# Incorrect :  124
# Undefined :  4
# User short days :  1
# Accuracy :  0.4144486692015209
# ======================================================================================================
# User :  00055d40d851.log.mv
# User lenght :  3726
# Correct :  738
# Incorrect :  6
# Undefined :  0
# User short days :  0
# Accuracy :  0.9892761394101877
# ======================================================================================================
# User :  003065016fe1.log.mv
# User lenght :  3810
# Correct :  374
# Incorrect :  267
# Undefined :  63
# User short days :  0
# Accuracy :  0.49081364829396323
# ======================================================================================================
# User :  0020e054d131.log.mv
# User lenght :  1141
# Correct :  34
# Incorrect :  160
# Undefined :  4
# User short days :  2
# Accuracy :  0.14847161572052403
# ======================================================================================================
# User :  0030651dc851.log.mv
# User lenght :  1936
# Correct :  230
# Incorrect :  75
# Undefined :  53
# User short days :  0
# Accuracy :  0.5927835051546392
# ======================================================================================================
# User :  000a8a733561.log.mv
# User lenght :  6054
# Correct :  631
# Incorrect :  529
# Undefined :  22
# User short days :  0
# Accuracy :  0.5210569777043765
# ======================================================================================================
# User :  000a411bbbb1.log.mv
# User lenght :  10912
# Correct :  1709
# Incorrect :  451
# Undefined :  0
# User short days :  0
# Accuracy :  0.7828676133760879
# ======================================================================================================
# User :  00306507da11.log.mv
# User lenght :  3344
# Correct :  324
# Incorrect :  249
# Undefined :  31
# User short days :  0
# Accuracy :  0.484304932735426
# ======================================================================================================
# User :  0030650764c1.log.mv
# User lenght :  7210
# Correct :  1314
# Incorrect :  44
# Undefined :  2
# User short days :  0
# Accuracy :  0.9112343966712899
# ======================================================================================================
# User :  000a8ab35bc1.log.mv
# User lenght :  5812
# Correct :  655
# Incorrect :  471
# Undefined :  12
# User short days :  0
# Accuracy :  0.5631986242476354
# ======================================================================================================
# User :  00306519e9d1.log.mv
# User lenght :  3016
# Correct :  459
# Incorrect :  110
# Undefined :  4
# User short days :  0
# Accuracy :  0.7599337748344371
# ======================================================================================================
# User :  00107a170ce1.log.mv
# User lenght :  35081
# Correct :  4455
# Incorrect :  2558
# Undefined :  0
# User short days :  0
# Accuracy :  0.6348867037195383
# ======================================================================================================
# Global results :
# ======================================================================================================
# Corrects :  1240582
# Incorrects :  799722
# Short days :  135295
# Undefined_Sequences :  4722
# Average Acc :  0.47455188705723483

# %% [markdown]
# # **Test Scenario 2** : Train on users and Test in other users

# %%
w=5
train_percentage_users = 0.5
threshold_lenght = 1000

method = 'HMM'

#undefined_strategy = 'None'
undefined_strategy = 'Markov'

path='/content/drive/My Drive/Mobility test/'


activate_HMM = True
otherwise_test_markov = False
if(undefined_strategy == 'Markov'):
  otherwise_test_markov = True

test_configuration ='Scenario:{0} W:{1} Method:{2} undefined_strategy:{3}.csv'.format(2,w,method,undefined_strategy)
print(test_configuration)
# Out:
# Scenario:2 W:5 Method:HMM undefined_strategy:Markov.csv

# %%
def train_on_many_users(train_files):

  global_models = None
  for filename in train_files:
    if filename.endswith("mv"):
      train_locations,train_days = Load_Data(os.path.join(path,filename))
      global_models = train_HMM(train_locations,train_days,w,global_models) 
  return global_models

# %%
list_of_files=os.listdir(path)
train_files,test_files =  Split_sequence(list_of_files,train_percentage_users)


print('Start model training')
global_models = train_on_many_users(train_files)
print('End model training')

Accuracies=[]
Corrects=[]
Incorrects=[]
Undefined=[]
Shortdays=[]
for filename in test_files :
    if filename.endswith("mv"):
      #Read sequence
      locations,days = Load_Data(os.path.join(path,filename))
      
      #Ignore sequence if the lenght is less than threshold_lenght
      if(len(locations)<threshold_lenght):
        continue

      #Split the sequence Train/Test
      train_locations,test_locations = Split_sequence(locations,train_percentage)
      train_days,test_days = Split_sequence(days,train_percentage)

      #Train the HMM model 
      models = None
      models = train_HMM(train_locations,train_days,w)

      #Convert the HMM model to normal markov model. This simple markove model use is used if a context is absent in the day model
      markov_model = train_markov_model(train_locations,w)

      #Test the Model 
      user_correct,user_incorrect,user_undefined,user_short_day,user_accuracy = test_user_HMM(models,
                                                                                              test_locations,
                                                                                              test_days,
                                                                                              w,
                                                                                              otherwise_markov=otherwise_test_markov,
                                                                                              markov_model=markov_model,
                                                                                              activate_HMM= activate_HMM)
      
      #Collect results
      Corrects.append(user_correct)
      Incorrects.append(user_incorrect)
      Undefined.append(user_undefined)
      Shortdays.append(user_short_day)
      Accuracies.append(user_accuracy)
      
      #Display results
      print('User : ', filename)
      print('User lenght : ',len(locations))
      print('Correct : ',user_correct )
      print('Incorrect : ',user_incorrect)
      print('Undefined : ',user_undefined)
      print('User short days : ',user_short_day)
      print('Accuracy : ',user_accuracy)
      print("======================================================================================================")

#Save final results in csv file where the name contains information about the test (w,method ....)The name of file is : Configuration.csv
save_results_csv(test_configuration,users_files,Corrects,Incorrects,Undefined,Shortdays,Accuracies)

print('Global results : ')
print("======================================================================================================")
print('Corrects : ',sum(Corrects))
print('Incorrects : ',sum(Incorrects))
print('Short days : ',sum(Undefined))
print('Undefined_Sequences : ',sum(Shortdays))
print('Average Acc : ',sum(Accuracies)/len(Accuracies))
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
# User :  000750615ac5.log.mv
# User lenght :  1022
# Correct :  4
# Incorrect :  8
# Undefined :  128
# User short days :  19
# Accuracy :  0.01951219512195122
# ======================================================================================================
# User :  00070e661235.log.mv
# User lenght :  1795
# Correct :  0
# Incorrect :  6
# Undefined :  213
# User short days :  14
# Accuracy :  0.0
# ======================================================================================================
# User :  000625a559b5.log.mv
# User lenght :  1844
# Correct :  229
# Incorrect :  44
# Undefined :  31
# User short days :  6
# Accuracy :  0.6205962059620597
# ======================================================================================================
# User :  00053cb1ad35.log.mv
# User lenght :  2856
# Correct :  111
# Incorrect :  114
# Undefined :  192
# User short days :  10
# Accuracy :  0.19405594405594406
# ======================================================================================================
# User :  00070e703c25.log.mv
# User lenght :  9966
# Correct :  1587
# Incorrect :  229
# Undefined :  118
# User short days :  23
# Accuracy :  0.7958876629889668
# ======================================================================================================
# User :  000625cb41a5.log.mv
# User lenght :  3999
# Correct :  713
# Incorrect :  0
# Undefined :  2
# User short days :  1
# Accuracy :  0.89125
# ======================================================================================================
# User :  0002b37d5ad5.log.mv
# User lenght :  2701
# Correct :  50
# Incorrect :  36
# Undefined :  335
# User short days :  7
# Accuracy :  0.09242144177449169
# ======================================================================================================
# User :  00053c0b5c65.log.mv
# User lenght :  7050
# Correct :  1031
# Incorrect :  157
# Undefined :  82
# User short days :  0
# Accuracy :  0.7312056737588652
# ======================================================================================================
# User :  0006259fd785.log.mv
# User lenght :  3245
# Correct :  186
# Incorrect :  171
# Undefined :  187
# User short days :  24
# Accuracy :  0.28659476117103233
# ======================================================================================================
# User :  003065097145.log.mv
# User lenght :  1535
# Correct :  239
# Incorrect :  28
# Undefined :  20
# User short days :  0
# Accuracy :  0.7785016286644951
# ======================================================================================================
# User :  0030650b29a5.log.mv
# User lenght :  3157
# Correct :  0
# Incorrect :  3
# Undefined :  449
# User short days :  5
# Accuracy :  0.0
# ======================================================================================================
# User :  003065370b25.log.mv
# User lenght :  6308
# Correct :  307
# Incorrect :  168
# Undefined :  482
# User short days :  17
# Accuracy :  0.2432646592709984
# ======================================================================================================
# User :  003065aeaa45.log.mv
# User lenght :  2821
# Correct :  199
# Incorrect :  110
# Undefined :  141
# User short days :  13
# Accuracy :  0.35221238938053095
# ======================================================================================================
# User :  000b5fc863c5.log.mv
# User lenght :  9577
# Correct :  1115
# Incorrect :  525
# Undefined :  221
# User short days :  0
# Accuracy :  0.5819415448851775
# ======================================================================================================
# User :  0030654c8515.log.mv
# User lenght :  1275
# Correct :  14
# Incorrect :  16
# Undefined :  120
# User short days :  7
# Accuracy :  0.054901960784313725
# ======================================================================================================
# User :  0030655b9345.log.mv
# User lenght :  1803
# Correct :  62
# Incorrect :  39
# Undefined :  170
# User short days :  8
# Accuracy :  0.17174515235457063
# ======================================================================================================
# User :  00306564c4a5.log.mv
# User lenght :  2593
# Correct :  247
# Incorrect :  17
# Undefined :  30
# User short days :  1
# Accuracy :  0.47591522157996147
# ======================================================================================================
# User :  0030656742f5.log.mv
# User lenght :  1597
# Correct :  99
# Incorrect :  30
# Undefined :  71
# User short days :  5
# Accuracy :  0.309375
# ======================================================================================================
# User :  000821aa0035.log.mv
# User lenght :  12056
# Correct :  1545
# Incorrect :  3
# Undefined :  739
# User short days :  58
# Accuracy :  0.6405472636815921
# ======================================================================================================
# User :  0030654d8615.log.mv
# User lenght :  6715
# Correct :  650
# Incorrect :  463
# Undefined :  95
# User short days :  12
# Accuracy :  0.48399106478034254
# ======================================================================================================
# User :  0030652529c5.log.mv
# User lenght :  2026
# Correct :  363
# Incorrect :  1
# Undefined :  12
# User short days :  5
# Accuracy :  0.8940886699507389
# ======================================================================================================
# User :  0030652cb0d5.log.mv
# User lenght :  1196
# Correct :  51
# Incorrect :  8
# Undefined :  121
# User short days :  18
# Accuracy :  0.2125
# ======================================================================================================
# User :  0030655b9b55.log.mv
# User lenght :  12329
# Correct :  1273
# Incorrect :  677
# Undefined :  341
# User short days :  11
# Accuracy :  0.5162206001622061
# ======================================================================================================
# User :  0030653bd165.log.mv
# User lenght :  3755
# Correct :  267
# Incorrect :  114
# Undefined :  170
# User short days :  22
# Accuracy :  0.355525965379494
# ======================================================================================================
# User :  0030659166b5.log.mv
# User lenght :  3515
# Correct :  218
# Incorrect :  156
# Undefined :  194
# User short days :  15
# Accuracy :  0.310099573257468
# ======================================================================================================
# User :  0030655f1785.log.mv
# User lenght :  2626
# Correct :  277
# Incorrect :  0
# Undefined :  69
# User short days :  6
# Accuracy :  0.526615969581749
# ======================================================================================================
# User :  00306583b135.log.mv
# User lenght :  2950
# Correct :  180
# Incorrect :  75
# Undefined :  150
# User short days :  12
# Accuracy :  0.3050847457627119
# ======================================================================================================
# User :  0030651fa2c5.log.mv
# User lenght :  10340
# Correct :  1275
# Incorrect :  149
# Undefined :  279
# User short days :  4
# Accuracy :  0.6165377176015474
# ======================================================================================================
# User :  00306518eb65.log.mv
# User lenght :  1360
# Correct :  14
# Incorrect :  12
# Undefined :  151
# User short days :  21
# Accuracy :  0.051470588235294115
# ======================================================================================================
# User :  0009b7fa20b5.log.mv
# User lenght :  1362
# Correct :  7
# Incorrect :  6
# Undefined :  165
# User short days :  17
# Accuracy :  0.02564102564102564
# ======================================================================================================
# User :  00306573cdf5.log.mv
# User lenght :  5135
# Correct :  374
# Incorrect :  339
# Undefined :  134
# User short days :  0
# Accuracy :  0.3641674780915287
# ======================================================================================================
# User :  003065542285.log.mv
# User lenght :  1112
# Correct :  0
# Incorrect :  0
# Undefined :  198
# User short days :  15
# Accuracy :  0.0
# ======================================================================================================
# User :  00306586db65.log.mv
# User lenght :  2266
# Correct :  38
# Incorrect :  8
# Undefined :  353
# User short days :  13
# Accuracy :  0.08370044052863436
# ======================================================================================================
# User :  00306593d275.log.mv
# User lenght :  17392
# Correct :  1731
# Incorrect :  419
# Undefined :  799
# User short days :  50
# Accuracy :  0.49755676918654784
# ======================================================================================================
# User :  003065e785d5.log.mv
# User lenght :  1144
# Correct :  31
# Incorrect :  15
# Undefined :  103
# User short days :  25
# Accuracy :  0.13537117903930132
# ======================================================================================================
# User :  0040966c3ca5.log.mv
# User lenght :  2913
# Correct :  52
# Incorrect :  17
# Undefined :  319
# User short days :  30
# Accuracy :  0.08919382504288165
# ======================================================================================================
# User :  004096b39235.log.mv
# User lenght :  3327
# Correct :  100
# Incorrect :  46
# Undefined :  260
# User short days :  9
# Accuracy :  0.15015015015015015
# ======================================================================================================
# User :  004096d75125.log.mv
# User lenght :  1537
# Correct :  2
# Incorrect :  3
# Undefined :  228
# User short days :  62
# Accuracy :  0.006493506493506494
# ======================================================================================================
# User :  003065f97eb5.log.mv
# User lenght :  1205
# Correct :  53
# Incorrect :  4
# Undefined :  69
# User short days :  14
# Accuracy :  0.21991701244813278
# ======================================================================================================
# User :  004096d98b75.log.mv
# User lenght :  2612
# Correct :  3
# Incorrect :  14
# Undefined :  306
# User short days :  24
# Accuracy :  0.0057361376673040155
# ======================================================================================================
# User :  0050dadbe785.log.mv
# User lenght :  1144
# Correct :  151
# Incorrect :  34
# Undefined :  14
# User short days :  1
# Accuracy :  0.6593886462882096
# ======================================================================================================
# User :  003065c11935.log.mv
# User lenght :  5489
# Correct :  164
# Incorrect :  73
# Undefined :  436
# User short days :  51
# Accuracy :  0.1493624772313297
# ======================================================================================================
# User :  0040960a6595.log.mv
# User lenght :  3272
# Correct :  42
# Incorrect :  62
# Undefined :  411
# User short days :  8
# Accuracy :  0.06412213740458016
# ======================================================================================================
# User :  0040963c1d25.log.mv
# User lenght :  3081
# Correct :  81
# Incorrect :  41
# Undefined :  400
# User short days :  4
# Accuracy :  0.1312803889789303
# ======================================================================================================
# User :  003065d453c5.log.mv
# User lenght :  1259
# Correct :  78
# Incorrect :  36
# Undefined :  38
# User short days :  6
# Accuracy :  0.30952380952380953
# ======================================================================================================
# User :  003065b21b85.log.mv
# User lenght :  2503
# Correct :  217
# Incorrect :  61
# Undefined :  83
# User short days :  1
# Accuracy :  0.43313373253493015
# ======================================================================================================
# User :  0000c5f2dae6.log.mv
# User lenght :  2490
# Correct :  492
# Incorrect :  1
# Undefined :  0
# User short days :  0
# Accuracy :  0.9879518072289156
# ======================================================================================================
# User :  003065d708e5.log.mv
# User lenght :  2582
# Correct :  2
# Incorrect :  8
# Undefined :  342
# User short days :  10
# Accuracy :  0.0038684719535783366
# ======================================================================================================
# User :  003065dba815.log.mv
# User lenght :  1931
# Correct :  15
# Incorrect :  5
# Undefined :  282
# User short days :  83
# Accuracy :  0.03875968992248062
# ======================================================================================================
# User :  003065bd27f5.log.mv
# User lenght :  4467
# Correct :  393
# Incorrect :  121
# Undefined :  250
# User short days :  2
# Accuracy :  0.4395973154362416
# ======================================================================================================
# User :  0040967ad665.log.mv
# User lenght :  1652
# Correct :  252
# Incorrect :  28
# Undefined :  21
# User short days :  0
# Accuracy :  0.7613293051359517
# ======================================================================================================
# User :  0050dac184a5.log.mv
# User lenght :  9890
# Correct :  1148
# Incorrect :  63
# Undefined :  392
# User short days :  2
# Accuracy :  0.5803842264914054
# ======================================================================================================
# User :  003065dca955.log.mv
# User lenght :  1046
# Correct :  58
# Incorrect :  0
# Undefined :  57
# User short days :  13
# Accuracy :  0.2761904761904762
# ======================================================================================================
# User :  003065c3dfa5.log.mv
# User lenght :  5028
# Correct :  618
# Incorrect :  238
# Undefined :  40
# User short days :  0
# Accuracy :  0.614314115308151
# ======================================================================================================
# User :  0030abb484a5.log.mv
# User lenght :  1082
# Correct :  102
# Incorrect :  43
# Undefined :  67
# User short days :  1
# Accuracy :  0.4700460829493088
# ======================================================================================================
# User :  003065c6cc25.log.mv
# User lenght :  1161
# Correct :  37
# Incorrect :  27
# Undefined :  69
# User short days :  21
# Accuracy :  0.15879828326180256
# ======================================================================================================
# User :  003065f10395.log.mv
# User lenght :  1188
# Correct :  71
# Incorrect :  10
# Undefined :  72
# User short days :  14
# Accuracy :  0.29831932773109243
# ======================================================================================================
# User :  004096f3e315.log.mv
# User lenght :  1679
# Correct :  5
# Incorrect :  8
# Undefined :  223
# User short days :  30
# Accuracy :  0.01488095238095238
# ======================================================================================================
# User :  004096a6a965.log.mv
# User lenght :  3797
# Correct :  5
# Incorrect :  6
# Undefined :  444
# User short days :  39
# Accuracy :  0.006578947368421052
# ======================================================================================================
# User :  003065be0615.log.mv
# User lenght :  1110
# Correct :  12
# Incorrect :  3
# Undefined :  112
# User short days :  20
# Accuracy :  0.05405405405405406
# ======================================================================================================
# User :  004096b28975.log.mv
# User lenght :  1485
# Correct :  6
# Incorrect :  4
# Undefined :  247
# User short days :  15
# Accuracy :  0.020202020202020204
# ======================================================================================================
# User :  003065b4c085.log.mv
# User lenght :  9700
# Correct :  485
# Incorrect :  298
# Undefined :  837
# User short days :  21
# Accuracy :  0.25
# ======================================================================================================
# User :  080046a567a5.log.mv
# User lenght :  1547
# Correct :  42
# Incorrect :  41
# Undefined :  127
# User short days :  4
# Accuracy :  0.13548387096774195
# ======================================================================================================
# User :  004096d86545.log.mv
# User lenght :  8892
# Correct :  707
# Incorrect :  37
# Undefined :  720
# User short days :  3
# Accuracy :  0.3974142776840922
# ======================================================================================================
# User :  00409686bf25.log.mv
# User lenght :  3224
# Correct :  300
# Incorrect :  121
# Undefined :  99
# User short days :  1
# Accuracy :  0.46511627906976744
# ======================================================================================================
# User :  00022d358176.log.mv
# User lenght :  1709
# Correct :  2
# Incorrect :  2
# Undefined :  283
# User short days :  43
# Accuracy :  0.005847953216374269
# ======================================================================================================
# User :  00022d3ed216.log.mv
# User lenght :  1882
# Correct :  26
# Incorrect :  18
# Undefined :  208
# User short days :  16
# Accuracy :  0.06896551724137931
# ======================================================================================================
# User :  00022d359b86.log.mv
# User lenght :  67280
# Correct :  10657
# Incorrect :  2361
# Undefined :  228
# User short days :  0
# Accuracy :  0.7919887039239001
# ======================================================================================================
# User :  00022d206286.log.mv
# User lenght :  29339
# Correct :  4643
# Incorrect :  18
# Undefined :  552
# User short days :  57
# Accuracy :  0.7912406271301977
# ======================================================================================================
# User :  00022d234446.log.mv
# User lenght :  1597
# Correct :  118
# Incorrect :  32
# Undefined :  65
# User short days :  12
# Accuracy :  0.36875
# ======================================================================================================
# User :  00022d20f446.log.mv
# User lenght :  4577
# Correct :  531
# Incorrect :  182
# Undefined :  93
# User short days :  0
# Accuracy :  0.5796943231441049
# ======================================================================================================
# User :  00022d17a6d6.log.mv
# User lenght :  1202
# Correct :  71
# Incorrect :  3
# Undefined :  57
# User short days :  7
# Accuracy :  0.2946058091286307
# ======================================================================================================
# User :  00022d44cfd6.log.mv
# User lenght :  1553
# Correct :  14
# Incorrect :  2
# Undefined :  220
# User short days :  41
# Accuracy :  0.04501607717041801
# ======================================================================================================
# User :  00022d0bd5b6.log.mv
# User lenght :  1115
# Correct :  6
# Incorrect :  0
# Undefined :  192
# User short days :  48
# Accuracy :  0.026905829596412557
# ======================================================================================================
# User :  00022d203896.log.mv
# User lenght :  1522
# Correct :  21
# Incorrect :  10
# Undefined :  144
# User short days :  22
# Accuracy :  0.06885245901639345
# ======================================================================================================
# User :  00022d00c776.log.mv
# User lenght :  3023
# Correct :  28
# Incorrect :  43
# Undefined :  444
# User short days :  6
# Accuracy :  0.04628099173553719
# ======================================================================================================
# User :  00022d0cdc36.log.mv
# User lenght :  3630
# Correct :  676
# Incorrect :  0
# Undefined :  0
# User short days :  0
# Accuracy :  0.931129476584022
# ======================================================================================================
# User :  00022d10ab86.log.mv
# User lenght :  5428
# Correct :  367
# Incorrect :  217
# Undefined :  287
# User short days :  3
# Accuracy :  0.3379373848987109
# ======================================================================================================
# User :  00022d3fd2f6.log.mv
# User lenght :  1600
# Correct :  109
# Incorrect :  50
# Undefined :  81
# User short days :  8
# Accuracy :  0.340625
# ======================================================================================================
# User :  00022d0c3b96.log.mv
# User lenght :  1099
# Correct :  9
# Incorrect :  10
# Undefined :  126
# User short days :  18
# Accuracy :  0.04090909090909091
# ======================================================================================================
# User :  00022d2997c6.log.mv
# User lenght :  1043
# Correct :  0
# Incorrect :  1
# Undefined :  173
# User short days :  10
# Accuracy :  0.0
# ======================================================================================================
# User :  00022d2a7f36.log.mv
# User lenght :  1058
# Correct :  11
# Incorrect :  4
# Undefined :  132
# User short days :  5
# Accuracy :  0.05188679245283019
# ======================================================================================================
# User :  00022d207e46.log.mv
# User lenght :  10806
# Correct :  1577
# Incorrect :  331
# Undefined :  99
# User short days :  19
# Accuracy :  0.7294172062904718
# ======================================================================================================
# User :  00022d0c1e26.log.mv
# User lenght :  2548
# Correct :  127
# Incorrect :  13
# Undefined :  245
# User short days :  22
# Accuracy :  0.24901960784313726
# ======================================================================================================
# User :  00022d52e056.log.mv
# User lenght :  2487
# Correct :  12
# Incorrect :  12
# Undefined :  334
# User short days :  37
# Accuracy :  0.024096385542168676
# ======================================================================================================
# User :  00022d781236.log.mv
# User lenght :  1820
# Correct :  62
# Incorrect :  85
# Undefined :  162
# User short days :  14
# Accuracy :  0.17032967032967034
# ======================================================================================================
# User :  00022d45d446.log.mv
# User lenght :  3673
# Correct :  381
# Incorrect :  138
# Undefined :  91
# User short days :  8
# Accuracy :  0.5183673469387755
# ======================================================================================================
# User :  00022da9f8f6.log.mv
# User lenght :  7995
# Correct :  178
# Incorrect :  6
# Undefined :  725
# User short days :  12
# Accuracy :  0.11131957473420888
# ======================================================================================================
# User :  00022d9a88d6.log.mv
# User lenght :  2671
# Correct :  196
# Incorrect :  53
# Undefined :  136
# User short days :  30
# Accuracy :  0.3663551401869159
# ======================================================================================================
# User :  00022d690a66.log.mv
# User lenght :  2272
# Correct :  85
# Incorrect :  34
# Undefined :  246
# User short days :  11
# Accuracy :  0.18681318681318682
# ======================================================================================================
# User :  00022d7d4e46.log.mv
# User lenght :  3518
# Correct :  314
# Incorrect :  176
# Undefined :  64
# User short days :  1
# Accuracy :  0.4460227272727273
# ======================================================================================================
# User :  00022d7ff066.log.mv
# User lenght :  5998
# Correct :  461
# Incorrect :  494
# Undefined :  220
# User short days :  1
# Accuracy :  0.38416666666666666
# ======================================================================================================
# User :  00022da4f596.log.mv
# User lenght :  1777
# Correct :  27
# Incorrect :  2
# Undefined :  287
# User short days :  115
# Accuracy :  0.07584269662921349
# ======================================================================================================
# User :  00022dae4796.log.mv
# User lenght :  2568
# Correct :  90
# Incorrect :  25
# Undefined :  244
# User short days :  27
# Accuracy :  0.17509727626459143
# ======================================================================================================
# User :  00022d981326.log.mv
# User lenght :  1853
# Correct :  3
# Incorrect :  0
# Undefined :  318
# User short days :  125
# Accuracy :  0.008086253369272238
# ======================================================================================================
# User :  00022da0c576.log.mv
# User lenght :  1667
# Correct :  0
# Incorrect :  0
# Undefined :  264
# User short days :  27
# Accuracy :  0.0
# ======================================================================================================
# User :  00022dacc066.log.mv
# User lenght :  1223
# Correct :  72
# Incorrect :  65
# Undefined :  73
# User short days :  1
# Accuracy :  0.2938775510204082
# ======================================================================================================
# User :  00022d4cadb6.log.mv
# User lenght :  2466
# Correct :  319
# Incorrect :  27
# Undefined :  28
# User short days :  7
# Accuracy :  0.645748987854251
# ======================================================================================================
# User :  00022d8b79e6.log.mv
# User lenght :  1220
# Correct :  6
# Incorrect :  6
# Undefined :  187
# User short days :  6
# Accuracy :  0.02459016393442623
# ======================================================================================================
# User :  00022d5a42d6.log.mv
# User lenght :  12319
# Correct :  1148
# Incorrect :  468
# Undefined :  553
# User short days :  14
# Accuracy :  0.4659090909090909
# ======================================================================================================
# User :  00022d790ea6.log.mv
# User lenght :  1997
# Correct :  188
# Incorrect :  61
# Undefined :  111
# User short days :  5
# Accuracy :  0.47
# ======================================================================================================
# User :  00022db0af76.log.mv
# User lenght :  28650
# Correct :  3966
# Incorrect :  628
# Undefined :  1016
# User short days :  36
# Accuracy :  0.6921465968586388
# ======================================================================================================
# User :  00022d997cb6.log.mv
# User lenght :  3791
# Correct :  257
# Incorrect :  264
# Undefined :  43
# User short days :  1
# Accuracy :  0.3386034255599473
# ======================================================================================================
# User :  00022d987006.log.mv
# User lenght :  11785
# Correct :  1712
# Incorrect :  564
# Undefined :  16
# User short days :  0
# Accuracy :  0.7263470513364446
# ======================================================================================================
# User :  00022dbcef66.log.mv
# User lenght :  11755
# Correct :  1575
# Incorrect :  529
# Undefined :  137
# User short days :  0
# Accuracy :  0.6699276903445343
# ======================================================================================================
# User :  00022df623b6.log.mv
# User lenght :  1668
# Correct :  2
# Incorrect :  4
# Undefined :  183
# User short days :  25
# Accuracy :  0.005988023952095809
# ======================================================================================================
# User :  00022dedee16.log.mv
# User lenght :  4229
# Correct :  467
# Incorrect :  121
# Undefined :  143
# User short days :  12
# Accuracy :  0.5520094562647754
# ======================================================================================================
# User :  00022dc27526.log.mv
# User lenght :  20082
# Correct :  3091
# Incorrect :  567
# Undefined :  209
# User short days :  2
# Accuracy :  0.7694797112272841
# ======================================================================================================
# User :  00022dc32046.log.mv
# User lenght :  1542
# Correct :  67
# Incorrect :  9
# Undefined :  133
# User short days :  23
# Accuracy :  0.2168284789644013
# ======================================================================================================
# User :  00022df53536.log.mv
# User lenght :  2218
# Correct :  2
# Incorrect :  6
# Undefined :  386
# User short days :  11
# Accuracy :  0.0045045045045045045
# ======================================================================================================
# User :  00022dc7bc36.log.mv
# User lenght :  15813
# Correct :  2284
# Incorrect :  600
# Undefined :  224
# User short days :  0
# Accuracy :  0.7220992728422384
# ======================================================================================================
# User :  00022dc5bee6.log.mv
# User lenght :  1177
# Correct :  89
# Incorrect :  15
# Undefined :  77
# User short days :  6
# Accuracy :  0.3771186440677966
# ======================================================================================================
# User :  00022deefdf6.log.mv
# User lenght :  8283
# Correct :  1376
# Incorrect :  98
# Undefined :  28
# User short days :  0
# Accuracy :  0.8304164152082076
# ======================================================================================================
# User :  00022dbc98a6.log.mv
# User lenght :  2553
# Correct :  63
# Incorrect :  86
# Undefined :  197
# User short days :  14
# Accuracy :  0.1232876712328767
# ======================================================================================================
# User :  00022ddd1706.log.mv
# User lenght :  7463
# Correct :  937
# Incorrect :  373
# Undefined :  53
# User short days :  0
# Accuracy :  0.6275954454119224
# ======================================================================================================
# User :  00022df12826.log.mv
# User lenght :  5816
# Correct :  759
# Incorrect :  92
# Undefined :  73
# User short days :  20
# Accuracy :  0.6520618556701031
# ======================================================================================================
# User :  00022dc20c36.log.mv
# User lenght :  2909
# Correct :  106
# Incorrect :  63
# Undefined :  268
# User short days :  23
# Accuracy :  0.18213058419243985
# ======================================================================================================
# User :  00022de0ca86.log.mv
# User lenght :  2150
# Correct :  77
# Incorrect :  13
# Undefined :  240
# User short days :  49
# Accuracy :  0.17906976744186046
# ======================================================================================================
# User :  00022dd99cc6.log.mv
# User lenght :  1030
# Correct :  0
# Incorrect :  0
# Undefined :  151
# User short days :  37
# Accuracy :  0.0
# ======================================================================================================
# User :  0006255c9046.log.mv
# User lenght :  1637
# Correct :  119
# Incorrect :  40
# Undefined :  114
# User short days :  7
# Accuracy :  0.3628048780487805
# ======================================================================================================
# User :  00045a4f11e6.log.mv
# User lenght :  3389
# Correct :  267
# Incorrect :  75
# Undefined :  286
# User short days :  23
# Accuracy :  0.3938053097345133
# ======================================================================================================
# User :  00053cb0c616.log.mv
# User lenght :  2533
# Correct :  148
# Incorrect :  113
# Undefined :  126
# User short days :  4
# Accuracy :  0.29191321499013806
# ======================================================================================================
# User :  00053c8c0216.log.mv
# User lenght :  3189
# Correct :  488
# Incorrect :  32
# Undefined :  63
# User short days :  7
# Accuracy :  0.7648902821316614
# ======================================================================================================
# User :  00055d3f9e36.log.mv
# User lenght :  9400
# Correct :  791
# Incorrect :  113
# Undefined :  916
# User short days :  1
# Accuracy :  0.4207446808510638
# ======================================================================================================
# User :  000625be4896.log.mv
# User lenght :  2683
# Correct :  501
# Incorrect :  1
# Undefined :  0
# User short days :  0
# Accuracy :  0.9329608938547486
# ======================================================================================================
# User :  00062554a2f6.log.mv
# User lenght :  3743
# Correct :  743
# Incorrect :  1
# Undefined :  0
# User short days :  0
# Accuracy :  0.9919893190921228
# ======================================================================================================
# User :  00022dfb6716.log.mv
# User lenght :  3496
# Correct :  122
# Incorrect :  79
# Undefined :  314
# User short days :  31
# Accuracy :  0.1742857142857143
# ======================================================================================================
# User :  00070e0da676.log.mv
# User lenght :  1196
# Correct :  2
# Incorrect :  4
# Undefined :  159
# User short days :  9
# Accuracy :  0.008333333333333333
# ======================================================================================================
# User :  00053c7d1536.log.mv
# User lenght :  1491
# Correct :  26
# Incorrect :  10
# Undefined :  188
# User short days :  40
# Accuracy :  0.08695652173913043
# ======================================================================================================
# User :  00053c95aa46.log.mv
# User lenght :  38649
# Correct :  5324
# Incorrect :  1961
# Undefined :  230
# User short days :  1
# Accuracy :  0.688745148771022
# ======================================================================================================
# User :  0002b38e4a86.log.mv
# User lenght :  9016
# Correct :  559
# Incorrect :  5
# Undefined :  1130
# User short days :  16
# Accuracy :  0.3098669623059867
# ======================================================================================================
# User :  00053c575656.log.mv
# User lenght :  1033
# Correct :  2
# Incorrect :  2
# Undefined :  138
# User short days :  25
# Accuracy :  0.00966183574879227
# ======================================================================================================
# User :  000625daa8c6.log.mv
# User lenght :  1155
# Correct :  71
# Incorrect :  61
# Undefined :  89
# User short days :  2
# Accuracy :  0.30735930735930733
# ======================================================================================================
# User :  000625e5b056.log.mv
# User lenght :  10903
# Correct :  1263
# Incorrect :  376
# Undefined :  457
# User short days :  9
# Accuracy :  0.579092159559835
# ======================================================================================================
# User :  00053c78fdf6.log.mv
# User lenght :  2844
# Correct :  262
# Incorrect :  120
# Undefined :  92
# User short days :  4
# Accuracy :  0.46045694200351495
# ======================================================================================================
# User :  00070e0ec886.log.mv
# User lenght :  29363
# Correct :  1464
# Incorrect :  1036
# Undefined :  3178
# User short days :  22
# Accuracy :  0.24927634939553892
# ======================================================================================================
# User :  0009b76a32c6.log.mv
# User lenght :  24275
# Correct :  2461
# Incorrect :  2279
# Undefined :  80
# User short days :  0
# Accuracy :  0.5069001029866117
# ======================================================================================================
# User :  003065294706.log.mv
# User lenght :  1295
# Correct :  37
# Incorrect :  31
# Undefined :  121
# User short days :  48
# Accuracy :  0.14285714285714285
# ======================================================================================================
# User :  0030652e6796.log.mv
# User lenght :  1052
# Correct :  142
# Incorrect :  0
# Undefined :  44
# User short days :  24
# Accuracy :  0.6729857819905213
# ======================================================================================================
# User :  00070e7040c6.log.mv
# User lenght :  2066
# Correct :  1
# Incorrect :  6
# Undefined :  272
# User short days :  27
# Accuracy :  0.0024154589371980675
# ======================================================================================================
# User :  0030651d9fe6.log.mv
# User lenght :  10732
# Correct :  1687
# Incorrect :  36
# Undefined :  274
# User short days :  29
# Accuracy :  0.7857475547275268
# ======================================================================================================
# User :  003065309e46.log.mv
# User lenght :  1828
# Correct :  105
# Incorrect :  15
# Undefined :  101
# User short days :  2
# Accuracy :  0.28688524590163933
# ======================================================================================================
# User :  000af4ba4a96.log.mv
# User lenght :  1920
# Correct :  221
# Incorrect :  30
# Undefined :  93
# User short days :  4
# Accuracy :  0.5755208333333334
# ======================================================================================================
# User :  000a8a45e0c6.log.mv
# User lenght :  1943
# Correct :  128
# Incorrect :  75
# Undefined :  136
# User short days :  3
# Accuracy :  0.32904884318766064
# ======================================================================================================
# User :  00070ea71ad6.log.mv
# User lenght :  1753
# Correct :  1
# Incorrect :  7
# Undefined :  318
# User short days :  7
# Accuracy :  0.002849002849002849
# ======================================================================================================
# User :  00306542b676.log.mv
# User lenght :  1032
# Correct :  1
# Incorrect :  4
# Undefined :  182
# User short days :  79
# Accuracy :  0.004830917874396135
# ======================================================================================================
# User :  0020e0e040c6.log.mv
# User lenght :  4694
# Correct :  476
# Incorrect :  186
# Undefined :  177
# User short days :  20
# Accuracy :  0.5069222577209798
# ======================================================================================================
# User :  003065239f46.log.mv
# User lenght :  3787
# Correct :  290
# Incorrect :  15
# Undefined :  353
# User short days :  148
# Accuracy :  0.38258575197889183
# ======================================================================================================
# User :  00070e96ba46.log.mv
# User lenght :  2615
# Correct :  193
# Incorrect :  20
# Undefined :  175
# User short days :  9
# Accuracy :  0.3690248565965583
# ======================================================================================================
# User :  000ab74d7a36.log.mv
# User lenght :  1989
# Correct :  156
# Incorrect :  28
# Undefined :  79
# User short days :  11
# Accuracy :  0.39195979899497485
# ======================================================================================================
# User :  000a4189d756.log.mv
# User lenght :  2713
# Correct :  152
# Incorrect :  106
# Undefined :  120
# User short days :  5
# Accuracy :  0.27992633517495397
# ======================================================================================================
# User :  0030651794b6.log.mv
# User lenght :  2112
# Correct :  0
# Incorrect :  0
# Undefined :  283
# User short days :  24
# Accuracy :  0.0
# ======================================================================================================
# User :  00070e195da6.log.mv
# User lenght :  6184
# Correct :  452
# Incorrect :  90
# Undefined :  420
# User short days :  20
# Accuracy :  0.3654001616814875
# ======================================================================================================
# User :  0030650e7e96.log.mv
# User lenght :  1273
# Correct :  51
# Incorrect :  14
# Undefined :  80
# User short days :  10
# Accuracy :  0.2
# ======================================================================================================
# User :  000a8a6cb9d6.log.mv
# User lenght :  3486
# Correct :  398
# Incorrect :  96
# Undefined :  119
# User short days :  3
# Accuracy :  0.5702005730659025
# ======================================================================================================
# User :  0030653dfa36.log.mv
# User lenght :  3060
# Correct :  2
# Incorrect :  2
# Undefined :  503
# User short days :  20
# Accuracy :  0.0032679738562091504
# ======================================================================================================
# User :  0030651e6b26.log.mv
# User lenght :  4851
# Correct :  219
# Incorrect :  65
# Undefined :  442
# User short days :  27
# Accuracy :  0.2255406797116375
# ======================================================================================================
# User :  00070ee42b16.log.mv
# User lenght :  1507
# Correct :  2
# Incorrect :  6
# Undefined :  154
# User short days :  17
# Accuracy :  0.006622516556291391
# ======================================================================================================
# User :  0030653a6e46.log.mv
# User lenght :  1620
# Correct :  151
# Incorrect :  60
# Undefined :  18
# User short days :  2
# Accuracy :  0.4660493827160494
# ======================================================================================================
# User :  0030656c5016.log.mv
# User lenght :  6488
# Correct :  578
# Incorrect :  149
# Undefined :  241
# User short days :  6
# Accuracy :  0.4453004622496148
# ======================================================================================================
# User :  003065d15da6.log.mv
# User lenght :  1912
# Correct :  27
# Incorrect :  0
# Undefined :  271
# User short days :  83
# Accuracy :  0.07049608355091384
# ======================================================================================================
# User :  003065ba6446.log.mv
# User lenght :  2318
# Correct :  0
# Incorrect :  0
# Undefined :  324
# User short days :  22
# Accuracy :  0.0
# ======================================================================================================
# User :  003065a48406.log.mv
# User lenght :  2050
# Correct :  62
# Incorrect :  4
# Undefined :  149
# User short days :  42
# Accuracy :  0.15121951219512195
# ======================================================================================================
# User :  0030657c51b6.log.mv
# User lenght :  3916
# Correct :  4
# Incorrect :  10
# Undefined :  515
# User short days :  23
# Accuracy :  0.00510204081632653
# ======================================================================================================
# User :  003065de1216.log.mv
# User lenght :  1571
# Correct :  17
# Incorrect :  21
# Undefined :  212
# User short days :  13
# Accuracy :  0.05396825396825397
# ======================================================================================================
# User :  0030657c49b6.log.mv
# User lenght :  4336
# Correct :  445
# Incorrect :  193
# Undefined :  40
# User short days :  0
# Accuracy :  0.5126728110599078
# ======================================================================================================
# User :  0030655123d6.log.mv
# User lenght :  2030
# Correct :  108
# Incorrect :  114
# Undefined :  159
# User short days :  2
# Accuracy :  0.2660098522167488
# ======================================================================================================
# User :  003065a9c4a6.log.mv
# User lenght :  1055
# Correct :  78
# Incorrect :  6
# Undefined :  27
# User short days :  5
# Accuracy :  0.3696682464454976
# ======================================================================================================
# User :  0030658b46f6.log.mv
# User lenght :  1963
# Correct :  15
# Incorrect :  10
# Undefined :  193
# User short days :  32
# Accuracy :  0.03816793893129771
# ======================================================================================================
# User :  003065bebdb6.log.mv
# User lenght :  1636
# Correct :  12
# Incorrect :  17
# Undefined :  194
# User short days :  32
# Accuracy :  0.036585365853658534
# ======================================================================================================
# User :  0030657dfb86.log.mv
# User lenght :  1705
# Correct :  124
# Incorrect :  40
# Undefined :  72
# User short days :  8
# Accuracy :  0.36363636363636365
# ======================================================================================================
# User :  003065929526.log.mv
# User lenght :  1945
# Correct :  20
# Incorrect :  18
# Undefined :  211
# User short days :  22
# Accuracy :  0.05141388174807198
# ======================================================================================================
# User :  0030659ff646.log.mv
# User lenght :  2691
# Correct :  0
# Incorrect :  0
# Undefined :  394
# User short days :  58
# Accuracy :  0.0
# ======================================================================================================
# User :  0030655b77a6.log.mv
# User lenght :  1349
# Correct :  14
# Incorrect :  13
# Undefined :  163
# User short days :  27
# Accuracy :  0.05185185185185185
# ======================================================================================================
# User :  003065b24ed6.log.mv
# User lenght :  3025
# Correct :  150
# Incorrect :  72
# Undefined :  268
# User short days :  2
# Accuracy :  0.24793388429752067
# ======================================================================================================
# User :  00306528bac1.log.mv
# User lenght :  1665
# Correct :  47
# Incorrect :  21
# Undefined :  165
# User short days :  53
# Accuracy :  0.14114114114114115
# ======================================================================================================
# User :  000ab7771501.log.mv
# User lenght :  11038
# Correct :  1097
# Incorrect :  728
# Undefined :  243
# User short days :  7
# Accuracy :  0.49682971014492755
# ======================================================================================================
# User :  000ab71a8381.log.mv
# User lenght :  1735
# Correct :  51
# Incorrect :  6
# Undefined :  250
# User short days :  7
# Accuracy :  0.14697406340057637
# ======================================================================================================
# User :  0009b7cc7c41.log.mv
# User lenght :  6195
# Correct :  850
# Incorrect :  262
# Undefined :  62
# User short days :  6
# Accuracy :  0.6860371267150929
# ======================================================================================================
# User :  0030650c0321.log.mv
# User lenght :  4943
# Correct :  827
# Incorrect :  4
# Undefined :  43
# User short days :  9
# Accuracy :  0.8361981799797775
# ======================================================================================================
# User :  000af4158581.log.mv
# User lenght :  8044
# Correct :  750
# Incorrect :  581
# Undefined :  223
# User short days :  0
# Accuracy :  0.4661280298321939
# ======================================================================================================
# User :  0030651dafd1.log.mv
# User lenght :  7751
# Correct :  994
# Incorrect :  170
# Undefined :  197
# User short days :  27
# Accuracy :  0.6408768536428111
# ======================================================================================================
# User :  003065366a61.log.mv
# User lenght :  7240
# Correct :  872
# Incorrect :  3
# Undefined :  113
# User short days :  21
# Accuracy :  0.6022099447513812
# ======================================================================================================
# User :  0030659cc9b1.log.mv
# User lenght :  4612
# Correct :  269
# Incorrect :  297
# Undefined :  77
# User short days :  3
# Accuracy :  0.2914409534127844
# ======================================================================================================
# User :  003065b6cd91.log.mv
# User lenght :  2111
# Correct :  45
# Incorrect :  57
# Undefined :  166
# User short days :  37
# Accuracy :  0.10638297872340426
# ======================================================================================================
# User :  0030654b8551.log.mv
# User lenght :  1480
# Correct :  118
# Incorrect :  59
# Undefined :  39
# User short days :  13
# Accuracy :  0.39864864864864863
# ======================================================================================================
# User :  0030655f6c81.log.mv
# User lenght :  1267
# Correct :  4
# Incorrect :  20
# Undefined :  205
# User short days :  1
# Accuracy :  0.015748031496062992
# ======================================================================================================
# User :  00306589f331.log.mv
# User lenght :  4029
# Correct :  307
# Incorrect :  95
# Undefined :  269
# User short days :  35
# Accuracy :  0.38089330024813894
# ======================================================================================================
# User :  003065afe4d1.log.mv
# User lenght :  1443
# Correct :  111
# Incorrect :  7
# Undefined :  56
# User short days :  2
# Accuracy :  0.38408304498269896
# ======================================================================================================
# User :  003065ae0321.log.mv
# User lenght :  6705
# Correct :  639
# Incorrect :  273
# Undefined :  119
# User short days :  2
# Accuracy :  0.47651006711409394
# ======================================================================================================
# User :  003065e8b691.log.mv
# User lenght :  2627
# Correct :  470
# Incorrect :  10
# Undefined :  16
# User short days :  1
# Accuracy :  0.8935361216730038
# ======================================================================================================
# User :  003065b312a1.log.mv
# User lenght :  1062
# Correct :  81
# Incorrect :  23
# Undefined :  29
# User short days :  4
# ...
# Correct :  56
# Incorrect :  31
# Undefined :  158
# User short days :  15
# Accuracy :  0.15774647887323945
# ======================================================================================================
# User :  00022d468591.log.mv
# User lenght :  1957
# Correct :  116
# Incorrect :  28
# Undefined :  143
# User short days :  2
# Accuracy :  0.29591836734693877
# ======================================================================================================
# User :  00022d3c5ba1.log.mv
# User lenght :  30366
# Correct :  4229
# Incorrect :  113
# Undefined :  1342
# User short days :  103
# Accuracy :  0.6962462956865327
# ======================================================================================================
# User :  00022d540de1.log.mv
# User lenght :  5276
# Correct :  575
# Incorrect :  86
# Undefined :  195
# User short days :  55
# Accuracy :  0.5445075757575758
# ======================================================================================================
# User :  00022d4887e1.log.mv
# User lenght :  2648
# Correct :  322
# Incorrect :  111
# Undefined :  52
# User short days :  5
# Accuracy :  0.6075471698113207
# ======================================================================================================
# User :  00022d5895d1.log.mv
# User lenght :  1223
# Correct :  52
# Incorrect :  23
# Undefined :  90
# User short days :  10
# Accuracy :  0.21224489795918366
# ======================================================================================================
# User :  00022d4364d1.log.mv
# User lenght :  2992
# Correct :  137
# Incorrect :  33
# Undefined :  329
# User short days :  11
# Accuracy :  0.2287145242070117
# ======================================================================================================
# User :  00022d3cb851.log.mv
# User lenght :  2286
# Correct :  359
# Incorrect :  61
# Undefined :  18
# User short days :  1
# Accuracy :  0.7838427947598253
# ======================================================================================================
# User :  00022d5a4d11.log.mv
# User lenght :  1314
# Correct :  3
# Incorrect :  2
# Undefined :  233
# User short days :  50
# Accuracy :  0.011406844106463879
# ======================================================================================================
# User :  00022d5f5601.log.mv
# User lenght :  1945
# Correct :  205
# Incorrect :  26
# Undefined :  33
# User short days :  0
# Accuracy :  0.5269922879177378
# ======================================================================================================
# User :  00022d423741.log.mv
# User lenght :  3138
# Correct :  94
# Incorrect :  70
# Undefined :  409
# User short days :  1
# Accuracy :  0.14968152866242038
# ======================================================================================================
# User :  00022d684ae1.log.mv
# User lenght :  3415
# Correct :  20
# Incorrect :  26
# Undefined :  527
# User short days :  9
# Accuracy :  0.029282576866764276
# ======================================================================================================
# User :  00022dc7ac01.log.mv
# User lenght :  11410
# Correct :  1544
# Incorrect :  63
# Undefined :  255
# User short days :  39
# Accuracy :  0.6765994741454864
# ======================================================================================================
# User :  00022dbc0cd1.log.mv
# User lenght :  1015
# Correct :  0
# Incorrect :  3
# Undefined :  120
# User short days :  23
# Accuracy :  0.0
# ======================================================================================================
# User :  00022dd6da91.log.mv
# User lenght :  2863
# Correct :  3
# Incorrect :  1
# Undefined :  469
# User short days :  136
# Accuracy :  0.005235602094240838
# ======================================================================================================
# User :  00022d906b31.log.mv
# User lenght :  1179
# Correct :  1
# Incorrect :  1
# Undefined :  199
# User short days :  51
# Accuracy :  0.00423728813559322
# ======================================================================================================
# User :  00022d9ee361.log.mv
# User lenght :  1340
# Correct :  26
# Incorrect :  6
# Undefined :  141
# User short days :  19
# Accuracy :  0.09701492537313433
# ======================================================================================================
# User :  00022d70f651.log.mv
# User lenght :  13295
# Correct :  1545
# Incorrect :  467
# Undefined :  522
# User short days :  1
# Accuracy :  0.5810455058292591
# ======================================================================================================
# User :  00022dc486c1.log.mv
# User lenght :  1061
# Correct :  29
# Incorrect :  16
# Undefined :  108
# User short days :  20
# Accuracy :  0.13615023474178403
# ======================================================================================================
# User :  00022dc76dc1.log.mv
# User lenght :  1446
# Correct :  7
# Incorrect :  8
# Undefined :  165
# User short days :  12
# Accuracy :  0.02413793103448276
# ======================================================================================================
# User :  00022dba8f51.log.mv
# User lenght :  34723
# Correct :  4498
# Incorrect :  1666
# Undefined :  626
# User short days :  0
# Accuracy :  0.6476601871850252
# ======================================================================================================
# User :  00022da80931.log.mv
# User lenght :  1208
# Correct :  59
# Incorrect :  40
# Undefined :  118
# User short days :  13
# Accuracy :  0.24380165289256198
# ======================================================================================================
# User :  00022d9300d1.log.mv
# User lenght :  1722
# Correct :  128
# Incorrect :  26
# Undefined :  111
# User short days :  23
# Accuracy :  0.3710144927536232
# ======================================================================================================
# User :  00022dc1a961.log.mv
# User lenght :  4327
# Correct :  667
# Incorrect :  25
# Undefined :  69
# User short days :  2
# Accuracy :  0.7702078521939953
# ======================================================================================================
# User :  00022d9f4221.log.mv
# User lenght :  1844
# Correct :  9
# Incorrect :  1
# Undefined :  309
# User short days :  86
# Accuracy :  0.024390243902439025
# ======================================================================================================
# User :  00022d89bdd1.log.mv
# User lenght :  1496
# Correct :  196
# Incorrect :  21
# Undefined :  18
# User short days :  2
# Accuracy :  0.6533333333333333
# ======================================================================================================
# User :  00022d707241.log.mv
# User lenght :  7429
# Correct :  1089
# Incorrect :  139
# Undefined :  143
# User short days :  0
# Accuracy :  0.7328398384925976
# ======================================================================================================
# User :  00022dc97ab1.log.mv
# User lenght :  1598
# Correct :  130
# Incorrect :  88
# Undefined :  62
# User short days :  1
# Accuracy :  0.40625
# ======================================================================================================
# User :  00022d9a2e21.log.mv
# User lenght :  1634
# Correct :  46
# Incorrect :  17
# Undefined :  144
# User short days :  58
# Accuracy :  0.14067278287461774
# ======================================================================================================
# User :  00022d8d7351.log.mv
# User lenght :  18042
# Correct :  2924
# Incorrect :  444
# Undefined :  126
# User short days :  0
# Accuracy :  0.8101967303962316
# ======================================================================================================
# User :  00022d8272f1.log.mv
# User lenght :  1266
# Correct :  177
# Incorrect :  3
# Undefined :  19
# User short days :  3
# Accuracy :  0.6968503937007874
# ======================================================================================================
# User :  00022dbffcb1.log.mv
# User lenght :  2641
# Correct :  269
# Incorrect :  99
# Undefined :  81
# User short days :  2
# Accuracy :  0.5085066162570888
# ======================================================================================================
# User :  00022daaf3d1.log.mv
# User lenght :  1667
# Correct :  56
# Incorrect :  34
# Undefined :  139
# User short days :  1
# Accuracy :  0.16766467065868262
# ======================================================================================================
# User :  00022de1c6c1.log.mv
# User lenght :  1437
# Correct :  95
# Incorrect :  2
# Undefined :  46
# User short days :  3
# Accuracy :  0.3298611111111111
# ======================================================================================================
# User :  00022dfdfb31.log.mv
# User lenght :  1914
# Correct :  70
# Incorrect :  40
# Undefined :  113
# User short days :  10
# Accuracy :  0.18276762402088773
# ======================================================================================================
# User :  00070e693f11.log.mv
# User lenght :  2274
# Correct :  226
# Incorrect :  201
# Undefined :  18
# User short days :  0
# Accuracy :  0.4967032967032967
# ======================================================================================================
# User :  00070ebde5d1.log.mv
# User lenght :  2120
# Correct :  71
# Incorrect :  56
# Undefined :  182
# User short days :  24
# Accuracy :  0.16745283018867924
# ======================================================================================================
# User :  00032f6d92b1 (1).log.mv
# User lenght :  6806
# Correct :  1007
# Incorrect :  46
# Undefined :  259
# User short days :  23
# Accuracy :  0.7393538913362702
# ======================================================================================================
# User :  00070eb92ba1.log.mv
# User lenght :  1286
# Correct :  1
# Incorrect :  1
# Undefined :  166
# User short days :  26
# Accuracy :  0.003875968992248062
# ======================================================================================================
# User :  000821f0dc31.log.mv
# User lenght :  1050
# Correct :  84
# Incorrect :  19
# Undefined :  87
# User short days :  29
# Accuracy :  0.4
# ======================================================================================================
# User :  00070e27c4f1.log.mv
# User lenght :  1815
# Correct :  13
# Incorrect :  18
# Undefined :  177
# User short days :  35
# Accuracy :  0.03581267217630854
# ======================================================================================================
# User :  00070ec8fba1.log.mv
# User lenght :  2567
# Correct :  61
# Incorrect :  39
# Undefined :  364
# User short days :  50
# Accuracy :  0.11867704280155641
# ======================================================================================================
# User :  00053c438691.log.mv
# User lenght :  1172
# Correct :  5
# Incorrect :  9
# Undefined :  131
# User short days :  33
# Accuracy :  0.02127659574468085
# ======================================================================================================
# User :  00032f6d92b1.log.mv
# User lenght :  6806
# Correct :  1007
# Incorrect :  46
# Undefined :  259
# User short days :  23
# Accuracy :  0.7393538913362702
# ======================================================================================================
# User :  0006257ec9f1.log.mv
# User lenght :  16846
# Correct :  2411
# Incorrect :  854
# Undefined :  0
# User short days :  0
# Accuracy :  0.7154302670623145
# ======================================================================================================
# User :  00022de96771.log.mv
# User lenght :  1314
# Correct :  62
# Incorrect :  25
# Undefined :  51
# User short days :  16
# Accuracy :  0.23574144486692014
# ======================================================================================================
# User :  00032f5418f1.log.mv
# User lenght :  3648
# Correct :  699
# Incorrect :  3
# Undefined :  13
# User short days :  0
# Accuracy :  0.9575342465753425
# ======================================================================================================
# User :  0007eba03671.log.mv
# User lenght :  2088
# Correct :  43
# Incorrect :  54
# Undefined :  176
# User short days :  10
# Accuracy :  0.10287081339712918
# ======================================================================================================
# User :  00032f98cf71.log.mv
# User lenght :  5081
# Correct :  299
# Incorrect :  57
# Undefined :  556
# User short days :  19
# Accuracy :  0.29400196656833827
# ======================================================================================================
# User :  0009b7a067c1.log.mv
# User lenght :  2038
# Correct :  84
# Incorrect :  72
# Undefined :  82
# User short days :  3
# Accuracy :  0.20588235294117646
# ======================================================================================================
# User :  00022de10371.log.mv
# User lenght :  1665
# Correct :  154
# Incorrect :  12
# Undefined :  97
# User short days :  6
# Accuracy :  0.4624624624624625
# ======================================================================================================
# User :  00053c81ed11.log.mv
# User lenght :  1313
# Correct :  31
# Incorrect :  22
# Undefined :  105
# User short days :  6
# Accuracy :  0.11787072243346007
# ======================================================================================================
# User :  00055d40d851.log.mv
# User lenght :  3726
# Correct :  726
# Incorrect :  7
# Undefined :  3
# User short days :  0
# Accuracy :  0.9731903485254692
# ======================================================================================================
# User :  003065016fe1.log.mv
# User lenght :  3810
# Correct :  131
# Incorrect :  39
# Undefined :  352
# User short days :  10
# Accuracy :  0.17191601049868765
# ======================================================================================================
# User :  0020e054d131.log.mv
# User lenght :  1141
# Correct :  0
# Incorrect :  2
# Undefined :  132
# User short days :  14
# Accuracy :  0.0
# ======================================================================================================
# User :  0030651dc851.log.mv
# User lenght :  1936
# Correct :  91
# Incorrect :  23
# Undefined :  149
# User short days :  5
# Accuracy :  0.2345360824742268
# ======================================================================================================
# User :  000a8a733561.log.mv
# User lenght :  6054
# Correct :  631
# Incorrect :  188
# Undefined :  267
# User short days :  4
# Accuracy :  0.5210569777043765
# ======================================================================================================
# User :  000a411bbbb1.log.mv
# User lenght :  10912
# Correct :  1748
# Incorrect :  243
# Undefined :  82
# User short days :  1
# Accuracy :  0.8007329363261567
# ======================================================================================================
# User :  00306507da11.log.mv
# User lenght :  3344
# Correct :  66
# Incorrect :  61
# Undefined :  257
# User short days :  8
# Accuracy :  0.09865470852017937
# ======================================================================================================
# User :  0030650764c1.log.mv
# User lenght :  7210
# Correct :  1079
# Incorrect :  8
# Undefined :  90
# User short days :  29
# Accuracy :  0.7482662968099861
# ======================================================================================================
# User :  000a8ab35bc1.log.mv
# User lenght :  5812
# Correct :  539
# Incorrect :  178
# Undefined :  361
# User short days :  8
# Accuracy :  0.46345657781599314
# ======================================================================================================
# User :  00306519e9d1.log.mv
# User lenght :  3016
# Correct :  322
# Incorrect :  89
# Undefined :  43
# User short days :  1
# Accuracy :  0.5331125827814569
# ======================================================================================================
# User :  00107a170ce1.log.mv
# User lenght :  35081
# Correct :  4538
# Incorrect :  2457
# Undefined :  2
# User short days :  0
# Accuracy :  0.6467151204218327
# ======================================================================================================
# Global results :
# ======================================================================================================
# Corrects :  524117
# Incorrects :  153905
# Short days :  238905
# Undefined_Sequences :  20063
# Average Acc :  0.3232184503307964
